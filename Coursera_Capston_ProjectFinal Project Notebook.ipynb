# %%
#import libraries

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
#Download data by BeautifulSoup

url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
res = requests.get(url).text
soup = BeautifulSoup(res, 'lxml')
table = soup.find('table', {'class':'wikitable sortable'})

# %%
#Creat a datafram for toronto refer to link
table_rows = table.find_all('tr')
data = []

for row in table_rows:
    td = []
    for t in row.find_all('td'):
        td.append(t.text.strip())
    data.append(td)
df = pd.DataFrame(data, columns = ['PostalCode', 'Borough', 'Neighborhood'])
df.head()
# Out:
#   PostalCode       Borough      Neighborhood
# 0       None          None              None
# 1        M1A  Not assigned      Not assigned
# 2        M2A  Not assigned      Not assigned
# 3        M3A    North York         Parkwoods
# 4        M4A    North York  Victoria Village

# %%
#Clean the data

df = df.dropna()
empty = 'Not assigned'
df = df[(df.PostalCode != empty) & (df.Borough != empty) & (df.Neighborhood != empty)]
df.head()
# Out:
#   PostalCode           Borough      Neighborhood
# 3        M3A        North York         Parkwoods
# 4        M4A        North York  Victoria Village
# 5        M5A  Downtown Toronto      Harbourfront
# 6        M5A  Downtown Toronto       Regent Park
# 7        M6A        North York  Lawrence Heights

# %%
df_final = df.groupby(['PostalCode', 'Borough'], sort = False).agg(','.join).reset_index()
df_final.head()
# Out:
#   PostalCode           Borough                     Neighborhood
# 0        M3A        North York                        Parkwoods
# 1        M4A        North York                 Victoria Village
# 2        M5A  Downtown Toronto         Harbourfront,Regent Park
# 3        M6A        North York  Lawrence Heights,Lawrence Manor
# 4        M9A         Etobicoke                 Islington Avenue

# %%
#To transform the coordinate file into the dataframe.

csv_file = 'http://cocl.us/Geospatial_data'
coordinates = pd.read_csv(csv_file)
coordinates.columns = ['PostalCode', 'Latitude', 'Longitude']
coordinates.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %%
#Merge coordinate in dataframe

df_merge = pd.merge(df_final, coordinates[['PostalCode','Latitude', 'Longitude']], on='PostalCode')
df_merge.head(10)
# Out:
#   PostalCode           Borough                     Neighborhood   Latitude  \
# 0        M3A        North York                        Parkwoods  43.753259
# 1        M4A        North York                 Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Harbourfront,Regent Park  43.654260
# 3        M6A        North York  Lawrence Heights,Lawrence Manor  43.718518
# 4        M9A         Etobicoke                 Islington Avenue  43.667856
# 5        M1B       Scarborough                    Rouge,Malvern  43.806686
# 6        M3B        North York                  Don Mills North  43.745906
# 7        M4B         East York   Woodbine Gardens,Parkview Hill  43.706397
# 8        M5B  Downtown Toronto          Ryerson,Garden District  43.657162
# 9        M6B        North York                        Glencairn  43.709577
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.532242
# 5 -79.194353
# 6 -79.352188
# 7 -79.309937
# 8 -79.378937
# 9 -79.445073

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

clr = "blue"
df_merge.groupby('Borough')['Neighborhood'].count().plot.bar(figsize = (20,8), color = clr)
plt.title('Neighborhood per Borough in Toronto', fontsize = 20)
plt.xlabel('Borough', fontsize = 12)
plt.ylabel('N. Neighborhoods', fontsize = 12)
plt.xticks(rotation = 'horizontal')
plt.show()

# %% [markdown]
# In the figure Neighborhood per Borough in Toronto, we can see that Mississauga has the least number of neighborhoods in all of ten buroughs.

# %% [markdown]
# Let's analyze how many Italian restaurants there are in each neighborhood.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# defining radius and limit of venues to get
radius=500
LIMIT=100

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Borough',
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_df = getNearbyVenues(names=df_merge['Borough'],
                                   latitudes=df_merge['Latitude'],
                                   longitudes=df_merge['Longitude']
                                  )
# Out:
# North York
# North York
# Downtown Toronto
# North York
# Etobicoke
# Scarborough
# North York
# East York
# Downtown Toronto
# North York
# Etobicoke
# Scarborough
# North York
# East York
# Downtown Toronto
# York
# Etobicoke
# Scarborough
# East Toronto
# Downtown Toronto
# York
# Scarborough
# East York
# Downtown Toronto
# Downtown Toronto
# Scarborough
# North York
# North York
# East York
# Downtown Toronto
# West Toronto
# Scarborough
# North York
# North York
# East York
# Downtown Toronto
# West Toronto
# Scarborough
# North York
# North York
# East Toronto
# Downtown Toronto
# West Toronto
# Scarborough
# North York
# North York
# East Toronto
# Downtown Toronto
# North York
# North York
# Scarborough
# North York
# North York
# East Toronto
# North York
# York
# North York
# Scarborough
# North York
# North York
# Central Toronto
# Central Toronto
# York
# York
# Scarborough
# North York
# Central Toronto
# Central Toronto
# West Toronto
# Etobicoke
# Scarborough
# North York
# Central Toronto
# Central Toronto
# West Toronto
# Mississauga
# Etobicoke
# Scarborough
# Central Toronto
# Downtown Toronto
# West Toronto
# Scarborough
# Central Toronto
# Downtown Toronto
# Scarborough
# Central Toronto
# Downtown Toronto
# Etobicoke
# Etobicoke
# Scarborough
# Downtown Toronto
# Downtown Toronto
# Etobicoke
# Etobicoke
# Scarborough
# Downtown Toronto
# Downtown Toronto
# Etobicoke
# Downtown Toronto
# East Toronto
# Etobicoke
# Etobicoke

# %%
toronto_df_neigh = getNearbyVenues(names=df_merge['Neighborhood'],
                                   latitudes=df_merge['Latitude'],
                                   longitudes=df_merge['Longitude']
                                  )
toronto_df_neigh.columns = ['Neighborhood',
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
# Out:
# Parkwoods
# Victoria Village
# Harbourfront,Regent Park
# Lawrence Heights,Lawrence Manor
# Islington Avenue
# Rouge,Malvern
# Don Mills North
# Woodbine Gardens,Parkview Hill
# Ryerson,Garden District
# Glencairn
# Cloverdale,Islington,Martin Grove,Princess Gardens,West Deane Park
# Highland Creek,Rouge Hill,Port Union
# Flemingdon Park,Don Mills South
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Bloordale Gardens,Eringate,Markland Wood,Old Burnhamthorpe
# Guildwood,Morningside,West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor,Downsview North,Wilson Heights
# Thorncliffe Park
# Adelaide,King,Richmond
# Dovercourt Village,Dufferin
# Scarborough Village
# Fairview,Henry Farm,Oriole
# Northwood Park,York University
# East Toronto
# Harbourfront East,Toronto Islands,Union Station
# Little Portugal,Trinity
# East Birchmount Park,Ionview,Kennedy Park
# Bayview Village
# CFB Toronto,Downsview East
# The Danforth West,Riverdale
# Design Exchange,Toronto Dominion Centre
# Brockton,Exhibition Place,Parkdale Village
# Clairlea,Golden Mile,Oakridge
# Silver Hills,York Mills
# Downsview West
# The Beaches West,India Bazaar
# Commerce Court,Victoria Hotel
# Downsview,North Park,Upwood Park
# Humber Summit
# Cliffcrest,Cliffside,Scarborough Village West
# Newtonbrook,Willowdale
# Downsview Central
# Studio District
# Bedford Park,Lawrence Manor East
# Del Ray,Keelesdale,Mount Dennis,Silverthorn
# Emery,Humberlea
# Birch Cliff,Cliffside West
# Willowdale South
# Downsview Northwest
# Lawrence Park
# Roselawn
# The Junction North,Runnymede
# Weston
# Dorset Park,Scarborough Town Centre,Wexford Heights
# York Mills West
# Davisville North
# Forest Hill North,Forest Hill West
# High Park,The Junction South
# Westmount
# Maryvale,Wexford
# Willowdale West
# North Toronto West
# The Annex,North Midtown,Yorkville
# Parkdale,Roncesvalles
# Canada Post Gateway Processing Centre
# Kingsview Village,Martin Grove Gardens,Richview Gardens,St. Phillips
# Agincourt
# Davisville
# Harbord,University of Toronto
# Runnymede,Swansea
# Clarks Corners,Sullivan,Tam O'Shanter
# Moore Park,Summerhill East
# Chinatown,Grange Park,Kensington Market
# Agincourt North,L'Amoreaux East,Milliken,Steeles East
# Deer Park,Forest Hill SE,Rathnelly,South Hill,Summerhill West
# CN Tower,Bathurst Quay,Island airport,Harbourfront West,King and Spadina,Railway Lands,South Niagara
# Humber Bay Shores,Mimico South,New Toronto
# Albion Gardens,Beaumond Heights,Humbergate,Jamestown,Mount Olive,Silverstone,South Steeles,Thistletown
# L'Amoreaux West
# Rosedale
# Stn A PO Boxes 25 The Esplanade
# Alderwood,Long Branch
# Northwest
# Upper Rouge
# Cabbagetown,St. James Town
# First Canadian Place,Underground city
# The Kingsway,Montgomery Road,Old Mill North
# Church and Wellesley
# Business Reply Mail Processing Centre 969 Eastern
# Humber Bay,King's Mill Park,Kingsway Park South East,Mimico NE,Old Mill South,The Queensway East,Royal York South East,Sunnylea
# Kingsway Park South West,Mimico NW,The Queensway West,Royal York South West,South of Bloor

# %%
toronto_df.head()
# Out:
#       Borough  Neighborhood Latitude  Neighborhood Longitude  \
# 0  North York              43.753259              -79.329656
# 1  North York              43.753259              -79.329656
# 2  North York              43.753259              -79.329656
# 3  North York              43.725882              -79.315572
# 4  North York              43.725882              -79.315572
#
#                     Venue  Venue Latitude  Venue Longitude     Venue Category
# 0         Brookbanks Park       43.751976       -79.332140               Park
# 1           Variety Store       43.751974       -79.333114  Food & Drink Shop
# 2           GreenWin pool       43.756232       -79.333842               Pool
# 3  Victoria Village Arena       43.723481       -79.315635       Hockey Arena
# 4             Tim Hortons       43.725517       -79.313103        Coffee Shop

# %%
toronto_df_neigh.head()
# Out:
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0         Parkwoods              43.753259              -79.329656
# 1         Parkwoods              43.753259              -79.329656
# 2         Parkwoods              43.753259              -79.329656
# 3  Victoria Village              43.725882              -79.315572
# 4  Victoria Village              43.725882              -79.315572
#
#                     Venue  Venue Latitude  Venue Longitude     Venue Category
# 0         Brookbanks Park       43.751976       -79.332140               Park
# 1           Variety Store       43.751974       -79.333114  Food & Drink Shop
# 2           GreenWin pool       43.756232       -79.333842               Pool
# 3  Victoria Village Arena       43.723481       -79.315635       Hockey Arena
# 4             Tim Hortons       43.725517       -79.313103        Coffee Shop

# %%
for i in range(len(toronto_df)):
    a="Restaurant"
    if a in toronto_df.loc[i,'Venue Category']:
        print(toronto_df.loc[i,:])
# Out:
# Borough                              North York
# Neighborhood Latitude                   43.7259
# Neighborhood Longitude                 -79.3156
# Venue                                 Portugril
# Venue Latitude                          43.7258
# Venue Longitude                        -79.3128
# Venue Category            Portuguese Restaurant
# Name: 5, dtype: object
# Borough                          North York
# Neighborhood Latitude               43.7259
# Neighborhood Longitude             -79.3156
# Venue                              The Frig
# Venue Latitude                      43.7271
# Venue Longitude                    -79.3174
# Venue Category            French Restaurant
# Name: 6, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6543
# Neighborhood Longitude            -79.3606
# Venue                       Impact Kitchen
# Venue Latitude                     43.6564
# Venue Longitude                    -79.357
# Venue Category                  Restaurant
# Name: 12, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6543
# Neighborhood Longitude              -79.3606
# Venue                              El Catrin
# Venue Latitude                       43.6506
# Venue Longitude                     -79.3589
# Venue Category            Mexican Restaurant
# Name: 29, dtype: object
# Borough                             Downtown Toronto
# Neighborhood Latitude                        43.6543
# Neighborhood Longitude                      -79.3606
# Venue                     Cluny Bistro & Boulangerie
# Venue Latitude                               43.6506
# Venue Longitude                             -79.3578
# Venue Category                     French Restaurant
# Name: 30, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6543
# Neighborhood Longitude              -79.3606
# Venue                       Cocina Economica
# Venue Latitude                        43.655
# Venue Longitude                     -79.3657
# Venue Category            Mexican Restaurant
# Name: 33, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6543
# Neighborhood Longitude            -79.3606
# Venue                     Souvlaki Express
# Venue Latitude                     43.6556
# Venue Longitude                   -79.3644
# Venue Category            Greek Restaurant
# Name: 45, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6543
# Neighborhood Longitude              -79.3606
# Venue                                 Archeo
# Venue Latitude                       43.6507
# Venue Longitude                     -79.3594
# Venue Category            Italian Restaurant
# Name: 47, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6543
# Neighborhood Longitude            -79.3606
# Venue                          Flame Shack
# Venue Latitude                     43.6568
# Venue Longitude                   -79.3589
# Venue Category                  Restaurant
# Name: 52, dtype: object
# Borough                                       North York
# Neighborhood Latitude                            43.7185
# Neighborhood Longitude                          -79.4648
# Venue                     Lac Vien Vietnamese Restaurant
# Venue Latitude                                   43.7213
# Venue Longitude                                 -79.4685
# Venue Category                     Vietnamese Restaurant
# Name: 58, dtype: object
# Borough                            Scarborough
# Neighborhood Latitude                  43.8067
# Neighborhood Longitude                -79.1944
# Venue                                  Wendy's
# Venue Latitude                         43.8074
# Venue Longitude                       -79.1991
# Venue Category            Fast Food Restaurant
# Name: 70, dtype: object
# Borough                             North York
# Neighborhood Latitude                  43.7459
# Neighborhood Longitude                -79.3522
# Venue                             Island Foods
# Venue Latitude                         43.7459
# Venue Longitude                        -79.346
# Venue Category            Caribbean Restaurant
# Name: 73, dtype: object
# Borough                            North York
# Neighborhood Latitude                 43.7459
# Neighborhood Longitude               -79.3522
# Venue                             Gonoe Sushi
# Venue Latitude                        43.7457
# Venue Longitude                       -79.346
# Venue Category            Japanese Restaurant
# Name: 75, dtype: object
# Borough                              East York
# Neighborhood Latitude                  43.7064
# Neighborhood Longitude                -79.3099
# Venue                                 Harvey's
# Venue Latitude                         43.7107
# Venue Longitude                       -79.3088
# Venue Category            Fast Food Restaurant
# Name: 81, dtype: object
# Borough                              East York
# Neighborhood Latitude                  43.7064
# Neighborhood Longitude                -79.3099
# Venue                                 Harvey's
# Venue Latitude                         43.7081
# Venue Longitude                       -79.3141
# Venue Category            Fast Food Restaurant
# Name: 85, dtype: object
# Borough                                  Downtown Toronto
# Neighborhood Latitude                             43.6572
# Neighborhood Longitude                           -79.3789
# Venue                     Hokkaido Ramen Santouka らーめん山頭火
# Venue Latitude                                    43.6564
# Venue Longitude                                  -79.3776
# Venue Category                           Ramen Restaurant
# Name: 95, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6572
# Neighborhood Longitude            -79.3789
# Venue                           Salad King
# Venue Latitude                     43.6576
# Venue Longitude                   -79.3816
# Venue Category             Thai Restaurant
# Name: 96, dtype: object
# Borough                                Downtown Toronto
# Neighborhood Latitude                           43.6572
# Neighborhood Longitude                         -79.3789
# Venue                                   Urban Herbivore
# Venue Latitude                                   43.655
# Venue Longitude                                -79.3809
# Venue Category            Vegetarian / Vegan Restaurant
# Name: 105, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6572
# Neighborhood Longitude               -79.3789
# Venue                                    JOEY
# Venue Latitude                        43.6561
# Venue Longitude                      -79.3819
# Venue Category            American Restaurant
# Name: 108, dtype: object
# Borough                         Downtown Toronto
# Neighborhood Latitude                    43.6572
# Neighborhood Longitude                  -79.3789
# Venue                     Kinka Izakaya Original
# Venue Latitude                           43.6606
# Venue Longitude                         -79.3789
# Venue Category               Japanese Restaurant
# Name: 113, dtype: object
# Borough                       Downtown Toronto
# Neighborhood Latitude                  43.6572
# Neighborhood Longitude                -79.3789
# Venue                          Crepe Delicious
# Venue Latitude                         43.6545
# Venue Longitude                       -79.3809
# Venue Category            Fast Food Restaurant
# Name: 117, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6572
# Neighborhood Longitude            -79.3789
# Venue                         Kinton Ramen
# Venue Latitude                     43.6606
# Venue Longitude                   -79.3789
# Venue Category            Ramen Restaurant
# Name: 119, dtype: object
# Borough                            Downtown Toronto
# Neighborhood Latitude                       43.6572
# Neighborhood Longitude                     -79.3789
# Venue                                 Kabul Express
# Venue Latitude                              43.6567
# Venue Longitude                            -79.3766
# Venue Category            Middle Eastern Restaurant
# Name: 122, dtype: object
# Borough                       Downtown Toronto
# Neighborhood Latitude                  43.6572
# Neighborhood Longitude                -79.3789
# Venue                               Milestones
# Venue Latitude                         43.6563
# Venue Longitude                       -79.3808
# Venue Category            Fast Food Restaurant
# Name: 125, dtype: object
# Borough                         Downtown Toronto
# Neighborhood Latitude                    43.6572
# Neighborhood Longitude                  -79.3789
# Venue                     Chipotle Mexican Grill
# Venue Latitude                           43.6569
# Venue Longitude                         -79.3809
# Venue Category                Mexican Restaurant
# Name: 130, dtype: object
# Borough                                   Downtown Toronto
# Neighborhood Latitude                              43.6572
# Neighborhood Longitude                            -79.3789
# Venue                     Scaddabush Italian Kitchen & Bar
# Venue Latitude                                     43.6589
# Venue Longitude                                   -79.3829
# Venue Category                          Italian Restaurant
# Name: 133, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6572
# Neighborhood Longitude              -79.3789
# Venue                            Red Lobster
# Venue Latitude                       43.6563
# Venue Longitude                     -79.3836
# Venue Category            Seafood Restaurant
# Name: 134, dtype: object
# Borough                             Downtown Toronto
# Neighborhood Latitude                        43.6572
# Neighborhood Longitude                      -79.3789
# Venue                        The Elm Tree Restaurant
# Venue Latitude                               43.6574
# Venue Longitude                             -79.3838
# Venue Category            Modern European Restaurant
# Name: 136, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6572
# Neighborhood Longitude              -79.3789
# Venue                     Trattoria Mercatto
# Venue Latitude                       43.6545
# Venue Longitude                      -79.381
# Venue Category            Italian Restaurant
# Name: 138, dtype: object
# Borough                            Downtown Toronto
# Neighborhood Latitude                       43.6572
# Neighborhood Longitude                     -79.3789
# Venue                          Paramount Fine Foods
# Venue Latitude                               43.655
# Venue Longitude                            -79.3802
# Venue Category            Middle Eastern Restaurant
# Name: 139, dtype: object
# Borough                           Downtown Toronto
# Neighborhood Latitude                      43.6572
# Neighborhood Longitude                    -79.3789
# Venue                     Jack Astor's Bar & Grill
# Venue Latitude                              43.656
# Venue Longitude                           -79.3803
# Venue Category                          Restaurant
# Name: 143, dtype: object
# Borough                       Downtown Toronto
# Neighborhood Latitude                  43.6572
# Neighborhood Longitude                -79.3789
# Venue                        Bourbon St. Grill
# Venue Latitude                         43.6551
# Venue Longitude                       -79.3808
# Venue Category            Fast Food Restaurant
# Name: 145, dtype: object
# Borough                         Downtown Toronto
# Neighborhood Latitude                    43.6572
# Neighborhood Longitude                  -79.3789
# Venue                     GB Hand-Pulled Noodles
# Venue Latitude                           43.6564
# Venue Longitude                         -79.3838
# Venue Category                Chinese Restaurant
# Name: 159, dtype: object
# Borough                       Downtown Toronto
# Neighborhood Latitude                  43.6572
# Neighborhood Longitude                -79.3789
# Venue                              Ethiopiques
# Venue Latitude                         43.6565
# Venue Longitude                       -79.3771
# Venue Category            Ethiopian Restaurant
# Name: 166, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6572
# Neighborhood Longitude               -79.3789
# Venue                                 Katsuya
# Venue Latitude                        43.6599
# Venue Longitude                      -79.3788
# Venue Category            Japanese Restaurant
# Name: 175, dtype: object
# Borough                        Downtown Toronto
# Neighborhood Latitude                   43.6572
# Neighborhood Longitude                 -79.3789
# Venue                           Fine Asian Bowl
# Venue Latitude                          43.6553
# Venue Longitude                        -79.3803
# Venue Category            Vietnamese Restaurant
# Name: 182, dtype: object
# Borough                                North York
# Neighborhood Latitude                     43.7096
# Neighborhood Longitude                   -79.4451
# Venue                     Miyako Sushi Restaurant
# Venue Latitude                            43.7091
# Venue Longitude                          -79.4439
# Venue Category                Japanese Restaurant
# Name: 187, dtype: object
# Borough                         North York
# Neighborhood Latitude              43.7096
# Neighborhood Longitude            -79.4451
# Venue                         Kokoro Sushi
# Venue Latitude                      43.709
# Venue Longitude                   -79.4441
# Venue Category            Sushi Restaurant
# Name: 189, dtype: object
# Borough                           North York
# Neighborhood Latitude                43.7259
# Neighborhood Longitude              -79.3409
# Venue                     Sorento Restaurant
# Venue Latitude                       43.7266
# Venue Longitude                      -79.342
# Venue Category            Italian Restaurant
# Name: 194, dtype: object
# Borough                                        North York
# Neighborhood Latitude                             43.7259
# Neighborhood Longitude                           -79.3409
# Venue                     Swiss Chalet Rotisserie & Grill
# Venue Latitude                                    43.7267
# Venue Longitude                                  -79.3414
# Venue Category                                 Restaurant
# Name: 197, dtype: object
# Borough                            North York
# Neighborhood Latitude                 43.7259
# Neighborhood Longitude               -79.3409
# Venue                       Memories of Japan
# Venue Latitude                        43.7273
# Venue Longitude                      -79.3414
# Venue Category            Japanese Restaurant
# Name: 200, dtype: object
# Borough                                     North York
# Neighborhood Latitude                          43.7259
# Neighborhood Longitude                        -79.3409
# Venue                     Genghis Khan Mongolian Grill
# Venue Latitude                                 43.7269
# Venue Longitude                               -79.3412
# Venue Category                        Asian Restaurant
# Name: 203, dtype: object
# Borough                           North York
# Neighborhood Latitude                43.7259
# Neighborhood Longitude              -79.3409
# Venue                           Asian Legend
# Venue Latitude                       43.7266
# Venue Longitude                     -79.3422
# Venue Category            Dim Sum Restaurant
# Name: 205, dtype: object
# Borough                           North York
# Neighborhood Latitude                43.7259
# Neighborhood Longitude              -79.3409
# Venue                       Congee Star 帝王名粥
# Venue Latitude                       43.7266
# Venue Longitude                     -79.3418
# Venue Category            Chinese Restaurant
# Name: 208, dtype: object
# Borough                             North York
# Neighborhood Latitude                  43.7259
# Neighborhood Longitude                -79.3409
# Venue                                 Harvey's
# Venue Latitude                         43.7266
# Venue Longitude                        -79.341
# Venue Category            Fast Food Restaurant
# Name: 211, dtype: object
# Borough                         North York
# Neighborhood Latitude              43.7259
# Neighborhood Longitude            -79.3409
# Venue                          Pho 88 發發餐廳
# Venue Latitude                     43.7266
# Venue Longitude                   -79.3423
# Venue Category            Asian Restaurant
# Name: 212, dtype: object
# Borough                        Downtown Toronto
# Neighborhood Latitude                   43.6515
# Neighborhood Longitude                 -79.3754
# Venue                     Gyu-Kaku Japanese BBQ
# Venue Latitude                          43.6514
# Venue Longitude                         -79.375
# Venue Category              Japanese Restaurant
# Name: 223, dtype: object
# Borough                    Downtown Toronto
# Neighborhood Latitude               43.6515
# Neighborhood Longitude             -79.3754
# Venue                     GEORGE Restaurant
# Venue Latitude                      43.6533
# Venue Longitude                    -79.3744
# Venue Category                   Restaurant
# Name: 224, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6515
# Neighborhood Longitude              -79.3754
# Venue                                Terroni
# Venue Latitude                       43.6509
# Venue Longitude                     -79.3756
# Venue Category            Italian Restaurant
# Name: 226, dtype: object
# Borough                            Downtown Toronto
# Neighborhood Latitude                       43.6515
# Neighborhood Longitude                     -79.3754
# Venue                                 Mystic Muffin
# Venue Latitude                              43.6525
# Venue Longitude                            -79.3727
# Venue Category            Middle Eastern Restaurant
# Name: 231, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6515
# Neighborhood Longitude               -79.3754
# Venue                                    NAMI
# Venue Latitude                        43.6509
# Venue Longitude                      -79.3759
# Venue Category            Japanese Restaurant
# Name: 233, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6515
# Neighborhood Longitude               -79.3754
# Venue                        Richmond Station
# Venue Latitude                        43.6516
# Venue Longitude                      -79.3793
# Venue Category            American Restaurant
# Name: 239, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6515
# Neighborhood Longitude            -79.3754
# Venue                       The Carbon Bar
# Venue Latitude                     43.6534
# Venue Longitude                    -79.375
# Venue Category                  Restaurant
# Name: 240, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6515
# Neighborhood Longitude              -79.3754
# Venue                                Carisma
# Venue Latitude                       43.6496
# Venue Longitude                     -79.3754
# Venue Category            Italian Restaurant
# Name: 245, dtype: object
# Borough                        Downtown Toronto
# Neighborhood Latitude                   43.6515
# Neighborhood Longitude                 -79.3754
# Venue                     La Bettola Di Terroni
# Venue Latitude                           43.652
# Venue Longitude                        -79.3781
# Venue Category               Italian Restaurant
# Name: 248, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6515
# Neighborhood Longitude            -79.3754
# Venue                            Sukhothai
# Venue Latitude                     43.6485
# Venue Longitude                   -79.3745
# Venue Category             Thai Restaurant
# Name: 251, dtype: object
# Borough                          Downtown Toronto
# Neighborhood Latitude                     43.6515
# Neighborhood Longitude                   -79.3754
# Venue                                   The Chase
# Venue Latitude                             43.651
# Venue Longitude                          -79.3794
# Venue Category            New American Restaurant
# Name: 253, dtype: object
# Borough                            Downtown Toronto
# Neighborhood Latitude                       43.6515
# Neighborhood Longitude                     -79.3754
# Venue                                          Leña
# Venue Latitude                              43.6518
# Venue Longitude                             -79.379
# Venue Category            Latin American Restaurant
# Name: 260, dtype: object
# Borough                        Downtown Toronto
# Neighborhood Latitude                   43.6515
# Neighborhood Longitude                 -79.3754
# Venue                     Victoria's Restaurant
# Venue Latitude                          43.6493
# Venue Longitude                        -79.3764
# Venue Category                       Restaurant
# Name: 262, dtype: object
# Borough                                Downtown Toronto
# Neighborhood Latitude                           43.6515
# Neighborhood Longitude                         -79.3754
# Venue                                    Fresh On Front
# Venue Latitude                                  43.6478
# Venue Longitude                                -79.3745
# Venue Category            Vegetarian / Vegan Restaurant
# Name: 273, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6515
# Neighborhood Longitude               -79.3754
# Venue                     Market Street Catch
# Venue Latitude                        43.6485
# Venue Longitude                      -79.3718
# Venue Category             Seafood Restaurant
# Name: 274, dtype: object
# Borough                                  Downtown Toronto
# Neighborhood Latitude                             43.6515
# Neighborhood Longitude                           -79.3754
# Venue                     The Works Gourmet Burger Bistro
# Venue Latitude                                    43.6487
# Venue Longitude                                  -79.3741
# Venue Category                                 Restaurant
# Name: 286, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6515
# Neighborhood Longitude              -79.3754
# Venue                      Buster's Sea Cove
# Venue Latitude                       43.6485
# Venue Longitude                     -79.3715
# Venue Category            Seafood Restaurant
# Name: 291, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6515
# Neighborhood Longitude               -79.3754
# Venue                           The Gabardine
# Venue Latitude                         43.651
# Venue Longitude                      -79.3812
# Venue Category            American Restaurant
# Name: 300, dtype: object
# Borough                          Downtown Toronto
# Neighborhood Latitude                     43.6515
# Neighborhood Longitude                   -79.3754
# Venue                              Loaded Pierogi
# Venue Latitude                             43.648
# Venue Longitude                          -79.3734
# Venue Category            Comfort Food Restaurant
# Name: 304, dtype: object
# Borough                    Downtown Toronto
# Neighborhood Latitude               43.6515
# Neighborhood Longitude             -79.3754
# Venue                       Schnitzel Queen
# Venue Latitude                      43.6542
# Venue Longitude                    -79.3705
# Venue Category            German Restaurant
# Name: 307, dtype: object
# Borough                    Downtown Toronto
# Neighborhood Latitude               43.6515
# Neighborhood Longitude             -79.3754
# Venue                         Biff's Bistro
# Venue Latitude                      43.6471
# Venue Longitude                    -79.3763
# Venue Category            French Restaurant
# Name: 308, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6515
# Neighborhood Longitude            -79.3754
# Venue                              Bannock
# Venue Latitude                     43.6521
# Venue Longitude                   -79.3812
# Venue Category                  Restaurant
# Name: 311, dtype: object
# Borough                                Downtown Toronto
# Neighborhood Latitude                           43.6515
# Neighborhood Longitude                         -79.3754
# Venue                     Vagabondo Ristorante & Lounge
# Venue Latitude                                  43.6482
# Venue Longitude                                -79.3753
# Venue Category                       Italian Restaurant
# Name: 315, dtype: object
# Borough                       Downtown Toronto
# Neighborhood Latitude                  43.6515
# Neighborhood Longitude                -79.3754
# Venue                                   B.GOOD
# Venue Latitude                         43.6496
# Venue Longitude                       -79.3712
# Venue Category            Fast Food Restaurant
# Name: 318, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6515
# Neighborhood Longitude              -79.3754
# Venue                               Mercatto
# Venue Latitude                       43.6502
# Venue Longitude                     -79.3808
# Venue Category            Italian Restaurant
# Name: 319, dtype: object
# Borough                          Scarborough
# Neighborhood Latitude                43.7636
# Neighborhood Longitude              -79.1887
# Venue                       Big Bite Burrito
# Venue Latitude                       43.7663
# Venue Longitude                     -79.1907
# Venue Category            Mexican Restaurant
# Name: 336, dtype: object
# Borough                                Downtown Toronto
# Neighborhood Latitude                           43.6448
# Neighborhood Longitude                         -79.3733
# Venue                                    Fresh On Front
# Venue Latitude                                  43.6478
# Venue Longitude                                -79.3745
# Venue Category            Vegetarian / Vegan Restaurant
# Name: 349, dtype: object
# Borough                    Downtown Toronto
# Neighborhood Latitude               43.6448
# Neighborhood Longitude             -79.3733
# Venue                         Biff's Bistro
# Venue Latitude                      43.6471
# Venue Longitude                    -79.3763
# Venue Category            French Restaurant
# Name: 355, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6448
# Neighborhood Longitude            -79.3733
# Venue                            Sukhothai
# Venue Latitude                     43.6485
# Venue Longitude                   -79.3745
# Venue Category             Thai Restaurant
# Name: 356, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6448
# Neighborhood Longitude               -79.3733
# Venue                     Market Street Catch
# Venue Latitude                        43.6485
# Venue Longitude                      -79.3718
# Venue Category             Seafood Restaurant
# Name: 357, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6448
# Neighborhood Longitude              -79.3733
# Venue                      Buster's Sea Cove
# Venue Latitude                       43.6485
# Venue Longitude                     -79.3715
# Venue Category            Seafood Restaurant
# Name: 366, dtype: object
# Borough                          Downtown Toronto
# Neighborhood Latitude                     43.6448
# Neighborhood Longitude                   -79.3733
# Venue                              Loaded Pierogi
# Venue Latitude                             43.648
# Venue Longitude                          -79.3734
# Venue Category            Comfort Food Restaurant
# Name: 371, dtype: object
# Borough                                 Downtown Toronto
# Neighborhood Latitude                            43.6448
# Neighborhood Longitude                          -79.3733
# Venue                     Alexandro's World Famous Gyros
# Venue Latitude                                   43.6417
# Venue Longitude                                 -79.3752
# Venue Category                          Greek Restaurant
# Name: 377, dtype: object
# Borough                       Downtown Toronto
# Neighborhood Latitude                  43.6448
# Neighborhood Longitude                -79.3733
# Venue                     Bier Markt Esplanade
# Venue Latitude                         43.6472
# Venue Longitude                       -79.3739
# Venue Category              Belgian Restaurant
# Name: 382, dtype: object
# Borough                                  Downtown Toronto
# Neighborhood Latitude                             43.6448
# Neighborhood Longitude                           -79.3733
# Venue                     The Works Gourmet Burger Bistro
# Venue Latitude                                    43.6487
# Venue Longitude                                  -79.3741
# Venue Category                                 Restaurant
# Name: 393, dtype: object
# Borough                                Downtown Toronto
# Neighborhood Latitude                           43.6448
# Neighborhood Longitude                         -79.3733
# Venue                     Vagabondo Ristorante & Lounge
# Venue Latitude                                  43.6482
# Venue Longitude                                -79.3753
# Venue Category                       Italian Restaurant
# Name: 397, dtype: object
# Borough                       Downtown Toronto
# Neighborhood Latitude                  43.6448
# Neighborhood Longitude                -79.3733
# Venue                     Bindia Indian Bistro
# Venue Latitude                         43.6486
# Venue Longitude                       -79.3718
# Venue Category               Indian Restaurant
# Name: 401, dtype: object
# Borough                                   York
# Neighborhood Latitude                   43.689
# Neighborhood Longitude                -79.4535
# Venue                                      KFC
# Venue Latitude                         43.6906
# Venue Longitude                       -79.4563
# Venue Category            Fast Food Restaurant
# Name: 403, dtype: object
# Borough                          Scarborough
# Neighborhood Latitude                 43.771
# Neighborhood Longitude              -79.2169
# Venue                     Korean Grill House
# Venue Latitude                       43.7708
# Venue Longitude                     -79.2145
# Venue Category             Korean Restaurant
# Name: 410, dtype: object
# Borough                         East York
# Neighborhood Latitude             43.7091
# Neighborhood Longitude           -79.3635
# Venue                     The Leaside Pub
# Venue Latitude                    43.7104
# Venue Longitude                  -79.3635
# Venue Category                 Restaurant
# Name: 416, dtype: object
# Borough                                     East York
# Neighborhood Latitude                         43.7091
# Neighborhood Longitude                       -79.3635
# Venue                     Kintako Japanese Restaurant
# Venue Latitude                                43.7116
# Venue Longitude                               -79.364
# Venue Category                       Sushi Restaurant
# Name: 421, dtype: object
# Borough                                           East York
# Neighborhood Latitude                               43.7091
# Neighborhood Longitude                             -79.3635
# Venue                     Mucho Burrito Fresh Mexican Grill
# Venue Latitude                                      43.7067
# Venue Longitude                                    -79.3617
# Venue Category                           Mexican Restaurant
# Name: 439, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                               Mercatto
# Venue Latitude                       43.6604
# Venue Longitude                     -79.3877
# Venue Category            Italian Restaurant
# Name: 449, dtype: object
# Borough                             Downtown Toronto
# Neighborhood Latitude                         43.658
# Neighborhood Longitude                      -79.3874
# Venue                        The Elm Tree Restaurant
# Venue Latitude                               43.6574
# Venue Longitude                             -79.3838
# Venue Category            Modern European Restaurant
# Name: 450, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude               43.658
# Neighborhood Longitude            -79.3874
# Venue                              Japango
# Venue Latitude                     43.6553
# Venue Longitude                   -79.3852
# Venue Category            Sushi Restaurant
# Name: 453, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                     Sansotei Ramen 三草亭
# Venue Latitude                       43.6552
# Venue Longitude                     -79.3865
# Venue Category              Ramen Restaurant
# Name: 454, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                            Red Lobster
# Venue Latitude                       43.6563
# Venue Longitude                     -79.3836
# Venue Category            Seafood Restaurant
# Name: 458, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                  43.658
# Neighborhood Longitude               -79.3874
# Venue                              Rolltation
# Venue Latitude                        43.6549
# Venue Longitude                      -79.3874
# Venue Category            Japanese Restaurant
# Name: 463, dtype: object
# Borough                                   Downtown Toronto
# Neighborhood Latitude                               43.658
# Neighborhood Longitude                            -79.3874
# Venue                     Scaddabush Italian Kitchen & Bar
# Venue Latitude                                     43.6589
# Venue Longitude                                   -79.3829
# Venue Category                          Italian Restaurant
# Name: 464, dtype: object
# Borough                        Downtown Toronto
# Neighborhood Latitude                    43.658
# Neighborhood Longitude                 -79.3874
# Venue                                   Nando's
# Venue Latitude                          43.6616
# Venue Longitude                        -79.3861
# Venue Category            Portuguese Restaurant
# Name: 472, dtype: object
# Borough                                Downtown Toronto
# Neighborhood Latitude                            43.658
# Neighborhood Longitude                         -79.3874
# Venue                                  Vegetarian Haven
# Venue Latitude                                   43.656
# Venue Longitude                                -79.3928
# Venue Category            Vegetarian / Vegan Restaurant
# Name: 476, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude               43.658
# Neighborhood Longitude            -79.3874
# Venue                           Salad King
# Venue Latitude                     43.6576
# Venue Longitude                   -79.3816
# Venue Category             Thai Restaurant
# Name: 479, dtype: object
# Borough                            Downtown Toronto
# Neighborhood Latitude                        43.658
# Neighborhood Longitude                     -79.3874
# Venue                                    Ali Baba's
# Venue Latitude                              43.6549
# Venue Longitude                            -79.3872
# Venue Category            Middle Eastern Restaurant
# Name: 480, dtype: object
# Borough                         Downtown Toronto
# Neighborhood Latitude                     43.658
# Neighborhood Longitude                  -79.3874
# Venue                     GB Hand-Pulled Noodles
# Venue Latitude                           43.6564
# Venue Longitude                         -79.3838
# Venue Category                Chinese Restaurant
# Name: 483, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                        Lebanon Express
# Venue Latitude                        43.661
# Venue Longitude                      -79.383
# Venue Category            Falafel Restaurant
# Name: 488, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                  43.658
# Neighborhood Longitude               -79.3874
# Venue                                    JOEY
# Venue Latitude                        43.6561
# Venue Longitude                      -79.3819
# Venue Category            American Restaurant
# Name: 490, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                          Sambuca Grill
# Venue Latitude                       43.6561
# Venue Longitude                     -79.3929
# Venue Category            Italian Restaurant
# Name: 497, dtype: object
# Borough                    Downtown Toronto
# Neighborhood Latitude                43.658
# Neighborhood Longitude             -79.3874
# Venue                           Midi Bistro
# Venue Latitude                      43.6559
# Venue Longitude                    -79.3921
# Venue Category            French Restaurant
# Name: 503, dtype: object
# Borough                    Downtown Toronto
# Neighborhood Latitude                43.658
# Neighborhood Longitude             -79.3874
# Venue                       Colaba Junction
# Venue Latitude                      43.6609
# Venue Longitude                    -79.3856
# Venue Category            Indian Restaurant
# Name: 513, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                  43.658
# Neighborhood Longitude               -79.3874
# Venue                                    Omai
# Venue Latitude                         43.656
# Venue Longitude                      -79.3925
# Venue Category            Japanese Restaurant
# Name: 518, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                                  Tosto
# Venue Latitude                       43.6612
# Venue Longitude                     -79.3864
# Venue Category            Italian Restaurant
# Name: 522, dtype: object
# Borough                    Downtown Toronto
# Neighborhood Latitude                43.658
# Neighborhood Longitude             -79.3874
# Venue                             Mo'Ramyun
# Venue Latitude                      43.6561
# Venue Longitude                    -79.3923
# Venue Category            Korean Restaurant
# Name: 527, dtype: object
# Borough                                             Downtown Toronto
# Neighborhood Latitude                                         43.658
# Neighborhood Longitude                                      -79.3874
# Venue                     Just Falafel  . . . Redefining Street Food
# Venue Latitude                                               43.6618
# Venue Longitude                                             -79.3861
# Venue Category                              Mediterranean Restaurant
# Name: 528, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6695
# Neighborhood Longitude              -79.4226
# Venue                         Vinny’s Panini
# Venue Latitude                       43.6707
# Venue Longitude                     -79.4261
# Venue Category            Italian Restaurant
# Name: 533, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6695
# Neighborhood Longitude            -79.4226
# Venue                           Actinolite
# Venue Latitude                     43.6679
# Venue Longitude                   -79.4281
# Venue Category                  Restaurant
# Name: 536, dtype: object
# Borough                           Scarborough
# Neighborhood Latitude                 43.7731
# Neighborhood Longitude               -79.2395
# Venue                     Federick Restaurant
# Venue Latitude                        43.7747
# Venue Longitude                      -79.2411
# Venue Category               Hakka Restaurant
# Name: 546, dtype: object
# Borough                                Scarborough
# Neighborhood Latitude                      43.7731
# Neighborhood Longitude                    -79.2395
# Venue                     Drupati's Roti & Doubles
# Venue Latitude                             43.7752
# Venue Longitude                           -79.2417
# Venue Category                Caribbean Restaurant
# Name: 547, dtype: object
# Borough                       Scarborough
# Neighborhood Latitude             43.7731
# Neighborhood Longitude           -79.2395
# Venue                         Thai One On
# Venue Latitude                    43.7745
# Venue Longitude                  -79.2413
# Venue Category            Thai Restaurant
# Name: 548, dtype: object
# Borough                                 North York
# Neighborhood Latitude                      43.8038
# Neighborhood Longitude                    -79.3635
# Venue                                 Villa Madina
# Venue Latitude                             43.8017
# Venue Longitude                           -79.3639
# Venue Category            Mediterranean Restaurant
# Name: 555, dtype: object
# Borough                   North York
# Neighborhood Latitude        43.7543
# Neighborhood Longitude      -79.4423
# Venue                     Bagel Plus
# Venue Latitude               43.7554
# Venue Longitude             -79.4407
# Venue Category            Restaurant
# Name: 558, dtype: object
# Borough                                  North York
# Neighborhood Latitude                       43.7543
# Neighborhood Longitude                     -79.4423
# Venue                       Orly Restaurant & Grill
# Venue Latitude                              43.7545
# Venue Longitude                            -79.4435
# Venue Category            Middle Eastern Restaurant
# Name: 560, dtype: object
# Borough                             North York
# Neighborhood Latitude                  43.7543
# Neighborhood Longitude                -79.4423
# Venue                              Dairy Queen
# Venue Latitude                         43.7557
# Venue Longitude                       -79.4402
# Venue Category            Fast Food Restaurant
# Name: 563, dtype: object
# Borough                         North York
# Neighborhood Latitude              43.7543
# Neighborhood Longitude            -79.4423
# Venue                         Wakame Sushi
# Venue Latitude                     43.7554
# Venue Longitude                   -79.4409
# Venue Category            Sushi Restaurant
# Name: 566, dtype: object
# Borough                                    East York
# Neighborhood Latitude                        43.7054
# Neighborhood Longitude                      -79.3494
# Venue                     Iqbal Kebab & Sweet Centre
# Venue Latitude                               43.7059
# Venue Longitude                             -79.3515
# Venue Category                     Indian Restaurant
# Name: 577, dtype: object
# Borough                           East York
# Neighborhood Latitude               43.7054
# Neighborhood Longitude             -79.3494
# Venue                          Hakka Garden
# Venue Latitude                      43.7046
# Venue Longitude                    -79.3498
# Venue Category            Indian Restaurant
# Name: 582, dtype: object
# Borough                                Downtown Toronto
# Neighborhood Latitude                           43.6506
# Neighborhood Longitude                         -79.3846
# Venue                                         Rosalinda
# Venue Latitude                                  43.6503
# Venue Longitude                                -79.3852
# Venue Category            Vegetarian / Vegan Restaurant
# Name: 597, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6506
# Neighborhood Longitude              -79.3846
# Venue                     Bosk at Shangri-La
# Venue Latitude                        43.649
# Venue Longitude                     -79.3858
# Venue Category              Asian Restaurant
# Name: 599, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6506
# Neighborhood Longitude            -79.3846
# Venue                     Estiatorio Volos
# Venue Latitude                     43.6503
# Venue Longitude                   -79.3845
# Venue Category            Greek Restaurant
# Name: 601, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6506
# Neighborhood Longitude            -79.3846
# Venue                          Noodle King
# Venue Latitude                     43.6517
# Venue Longitude                    -79.383
# Venue Category            Asian Restaurant
# Name: 603, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6506
# Neighborhood Longitude               -79.3846
# Venue                        Cactus Club Cafe
# Venue Latitude                        43.6496
# Venue Longitude                      -79.3817
# Venue Category            American Restaurant
# Name: 610, dtype: object
# Borough                           Downtown Toronto
# Neighborhood Latitude                      43.6506
# Neighborhood Longitude                    -79.3846
# Venue                     John & Sons Oyster House
# Venue Latitude                             43.6507
# Venue Longitude                           -79.3816
# Venue Category                  Seafood Restaurant
# Name: 612, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6506
# Neighborhood Longitude            -79.3846
# Venue                             JaBistro
# Venue Latitude                     43.6497
# Venue Longitude                   -79.3881
# Venue Category            Sushi Restaurant
# Name: 617, dtype: object
# Borough                       Downtown Toronto
# Neighborhood Latitude                  43.6506
# Neighborhood Longitude                -79.3846
# Venue                                    Kojin
# Venue Latitude                         43.6494
# Venue Longitude                       -79.3861
# Venue Category            Colombian Restaurant
# Name: 622, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6506
# Neighborhood Longitude               -79.3846
# Venue                           The Gabardine
# Venue Latitude                         43.651
# Venue Longitude                      -79.3812
# Venue Category            American Restaurant
# Name: 626, dtype: object
# Borough                           Downtown Toronto
# Neighborhood Latitude                      43.6506
# Neighborhood Longitude                    -79.3846
# Venue                     Fune Japanese Restaurant
# Venue Latitude                             43.6485
# Venue Longitude                           -79.3865
# Venue Category                 Japanese Restaurant
# Name: 634, dtype: object
# Borough                               Downtown Toronto
# Neighborhood Latitude                          43.6506
# Neighborhood Longitude                        -79.3846
# Venue                     Copacabana Grilled Brazilian
# Venue Latitude                                 43.6483
# Venue Longitude                               -79.3882
# Venue Category                    Brazilian Restaurant
# Name: 636, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6506
# Neighborhood Longitude            -79.3846
# Venue                                  Pai
# Venue Latitude                     43.6479
# Venue Longitude                   -79.3886
# Venue Category             Thai Restaurant
# Name: 641, dtype: object
# Borough                      Downtown Toronto
# ...
# Venue Latitude                        43.6462
# Venue Longitude                      -79.3831
# Venue Category                     Restaurant
# Name: 2038, dtype: object
# Borough                          Downtown Toronto
# Neighborhood Latitude                     43.6484
# Neighborhood Longitude                   -79.3823
# Venue                                   The Chase
# Venue Latitude                             43.651
# Venue Longitude                          -79.3794
# Venue Category            New American Restaurant
# Name: 2044, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6484
# Neighborhood Longitude              -79.3823
# Venue                      Buster's Sea Cove
# Venue Latitude                       43.6478
# Venue Longitude                     -79.3792
# Venue Category            Seafood Restaurant
# Name: 2046, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6484
# Neighborhood Longitude               -79.3823
# Venue                        Richmond Station
# Venue Latitude                        43.6516
# Venue Longitude                      -79.3793
# Venue Category            American Restaurant
# Name: 2047, dtype: object
# Borough                           Downtown Toronto
# Neighborhood Latitude                      43.6484
# Neighborhood Longitude                    -79.3823
# Venue                     John & Sons Oyster House
# Venue Latitude                             43.6506
# Venue Longitude                           -79.3816
# Venue Category                  Seafood Restaurant
# Name: 2057, dtype: object
# Borough                                   Downtown Toronto
# Neighborhood Latitude                              43.6484
# Neighborhood Longitude                            -79.3823
# Venue                     Ruby Thai (First Canadian Place)
# Venue Latitude                                     43.6491
# Venue Longitude                                   -79.3816
# Venue Category                             Thai Restaurant
# Name: 2059, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6484
# Neighborhood Longitude              -79.3823
# Venue                               Mercatto
# Venue Latitude                       43.6502
# Venue Longitude                     -79.3808
# Venue Category            Italian Restaurant
# Name: 2061, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6484
# Neighborhood Longitude            -79.3823
# Venue                          Noodle King
# Venue Latitude                     43.6517
# Venue Longitude                    -79.383
# Venue Category            Asian Restaurant
# Name: 2064, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6484
# Neighborhood Longitude            -79.3823
# Venue                     Marché Mövenpick
# Venue Latitude                     43.6473
# Venue Longitude                   -79.3786
# Venue Category                  Restaurant
# Name: 2066, dtype: object
# Borough                           Downtown Toronto
# Neighborhood Latitude                      43.6484
# Neighborhood Longitude                    -79.3823
# Venue                     Fune Japanese Restaurant
# Venue Latitude                             43.6485
# Venue Longitude                           -79.3865
# Venue Category                 Japanese Restaurant
# Name: 2068, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6484
# Neighborhood Longitude            -79.3823
# Venue                           Sweet Lulu
# Venue Latitude                     43.6506
# Venue Longitude                   -79.3812
# Venue Category            Asian Restaurant
# Name: 2071, dtype: object
# Borough                       Downtown Toronto
# Neighborhood Latitude                  43.6484
# Neighborhood Longitude                -79.3823
# Venue                                    Kojin
# Venue Latitude                         43.6494
# Venue Longitude                       -79.3861
# Venue Category            Colombian Restaurant
# Name: 2075, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6484
# Neighborhood Longitude            -79.3823
# Venue                          Thai Island
# Venue Latitude                     43.6491
# Venue Longitude                   -79.3838
# Venue Category             Thai Restaurant
# Name: 2077, dtype: object
# Borough                           Downtown Toronto
# Neighborhood Latitude                      43.6484
# Neighborhood Longitude                    -79.3823
# Venue                               Byblos Toronto
# Venue Latitude                             43.6476
# Venue Longitude                           -79.3884
# Venue Category            Mediterranean Restaurant
# Name: 2081, dtype: object
# Borough                               Downtown Toronto
# Neighborhood Latitude                          43.6484
# Neighborhood Longitude                        -79.3823
# Venue                     Copacabana Grilled Brazilian
# Venue Latitude                                 43.6483
# Venue Longitude                               -79.3882
# Venue Category                    Brazilian Restaurant
# Name: 2084, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6659
# Neighborhood Longitude            -79.3832
# Venue                     Storm Crow Manor
# Venue Latitude                     43.6668
# Venue Longitude                   -79.3816
# Venue Category            Theme Restaurant
# Name: 2097, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6659
# Neighborhood Longitude              -79.3832
# Venue                     Sansotei Ramen 三草亭
# Venue Latitude                       43.6667
# Venue Longitude                     -79.3854
# Venue Category              Ramen Restaurant
# Name: 2101, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6659
# Neighborhood Longitude            -79.3832
# Venue                             Fabarnak
# Venue Latitude                     43.6664
# Venue Longitude                    -79.381
# Venue Category                  Restaurant
# Name: 2102, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6659
# Neighborhood Longitude              -79.3832
# Venue                           Como En Casa
# Venue Latitude                       43.6652
# Venue Longitude                     -79.3848
# Venue Category            Mexican Restaurant
# Name: 2104, dtype: object
# Borough                               Downtown Toronto
# Neighborhood Latitude                          43.6659
# Neighborhood Longitude                        -79.3832
# Venue                     Dal Moro's Fresh Pasta To Go
# Venue Latitude                                 43.6666
# Venue Longitude                               -79.3854
# Venue Category                      Italian Restaurant
# Name: 2119, dtype: object
# Borough                        Downtown Toronto
# Neighborhood Latitude                   43.6659
# Neighborhood Longitude                 -79.3832
# Venue                     Kothur Indian Cuisine
# Venue Latitude                          43.6679
# Venue Longitude                        -79.3857
# Venue Category                Indian Restaurant
# Name: 2120, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6659
# Neighborhood Longitude            -79.3832
# Venue                               Si Lom
# Venue Latitude                      43.665
# Venue Longitude                   -79.3807
# Venue Category             Thai Restaurant
# Name: 2121, dtype: object
# Borough                        Downtown Toronto
# Neighborhood Latitude                   43.6659
# Neighborhood Longitude                 -79.3832
# Venue                                    Ginger
# Venue Latitude                          43.6654
# Venue Longitude                        -79.3808
# Venue Category            Vietnamese Restaurant
# Name: 2122, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6659
# Neighborhood Longitude            -79.3832
# Venue                          Tokyo Sushi
# Venue Latitude                     43.6659
# Venue Longitude                    -79.387
# Venue Category            Sushi Restaurant
# Name: 2134, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6659
# Neighborhood Longitude            -79.3832
# Venue                                 Wish
# Venue Latitude                     43.6688
# Venue Longitude                   -79.3857
# Venue Category                  Restaurant
# Name: 2137, dtype: object
# Borough                    Downtown Toronto
# Neighborhood Latitude               43.6659
# Neighborhood Longitude             -79.3832
# Venue                        Loaded Pierogi
# Venue Latitude                      43.6647
# Venue Longitude                    -79.3806
# Venue Category            Polish Restaurant
# Name: 2141, dtype: object
# Borough                           Downtown Toronto
# Neighborhood Latitude                      43.6659
# Neighborhood Longitude                    -79.3832
# Venue                     Tabriz Persian Cookhouse
# Venue Latitude                             43.6653
# Venue Longitude                           -79.3875
# Venue Category                  Persian Restaurant
# Name: 2144, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6659
# Neighborhood Longitude            -79.3832
# Venue                           Wow! Sushi
# Venue Latitude                     43.6685
# Venue Longitude                   -79.3867
# Venue Category            Sushi Restaurant
# Name: 2150, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6659
# Neighborhood Longitude               -79.3832
# Venue                              Kawa Sushi
# Venue Latitude                        43.6639
# Venue Longitude                      -79.3802
# Venue Category            Japanese Restaurant
# Name: 2152, dtype: object
# Borough                           Downtown Toronto
# Neighborhood Latitude                      43.6659
# Neighborhood Longitude                    -79.3832
# Venue                                  Constantine
# Venue Latitude                             43.6688
# Venue Longitude                           -79.3853
# Venue Category            Mediterranean Restaurant
# Name: 2153, dtype: object
# Borough                           Downtown Toronto
# Neighborhood Latitude                      43.6659
# Neighborhood Longitude                    -79.3832
# Venue                              The Salad House
# Venue Latitude                             43.6695
# Venue Longitude                           -79.3861
# Venue Category            Mediterranean Restaurant
# Name: 2155, dtype: object
# Borough                    Downtown Toronto
# Neighborhood Latitude               43.6659
# Neighborhood Longitude             -79.3832
# Venue                          Naan & Kabob
# Venue Latitude                       43.669
# Venue Longitude                    -79.3862
# Venue Category            Afghan Restaurant
# Name: 2156, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6659
# Neighborhood Longitude               -79.3832
# Venue                         The Blake House
# Venue Latitude                        43.6645
# Venue Longitude                      -79.3775
# Venue Category            American Restaurant
# Name: 2157, dtype: object
# Borough                     Downtown Toronto
# Neighborhood Latitude                43.6659
# Neighborhood Longitude              -79.3832
# Venue                     The Captain's Boil
# Venue Latitude                       43.6624
# Venue Longitude                     -79.3835
# Venue Category            Seafood Restaurant
# Name: 2160, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6659
# Neighborhood Longitude               -79.3832
# Venue                           Onnki Donburi
# Venue Latitude                        43.6698
# Venue Longitude                      -79.3846
# Venue Category            Japanese Restaurant
# Name: 2161, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6659
# Neighborhood Longitude            -79.3832
# Venue                           Rolltation
# Venue Latitude                     43.6694
# Venue Longitude                   -79.3866
# Venue Category            Sushi Restaurant
# Name: 2162, dtype: object
# Borough                       Downtown Toronto
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                      Ritz Caribbean Food
# Venue Latitude                         43.6695
# Venue Longitude                       -79.3865
# Venue Category            Caribbean Restaurant
# Name: 2164, dtype: object
# Borough                       Downtown Toronto
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                     Okonomi House お好みハウス
# Venue Latitude                         43.6684
# Venue Longitude                       -79.3869
# Venue Category             Japanese Restaurant
# Name: 2165, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6659
# Neighborhood Longitude            -79.3832
# Venue                              O. Noir
# Venue Latitude                     43.6691
# Venue Longitude                   -79.3825
# Venue Category                  Restaurant
# Name: 2166, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6659
# Neighborhood Longitude               -79.3832
# Venue                          Kokoni Izakaya
# Venue Latitude                        43.6642
# Venue Longitude                      -79.3803
# Venue Category            Japanese Restaurant
# Name: 2171, dtype: object
# Borough                   Downtown Toronto
# Neighborhood Latitude              43.6659
# Neighborhood Longitude            -79.3832
# Venue                          Asahi Sushi
# Venue Latitude                     43.6699
# Venue Longitude                   -79.3829
# Venue Category            Sushi Restaurant
# Name: 2176, dtype: object
# Borough                       Downtown Toronto
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                               A&W Canada
# Venue Latitude                         43.6664
# Venue Longitude                       -79.3782
# Venue Category            Fast Food Restaurant
# Name: 2178, dtype: object
# Borough                      Downtown Toronto
# Neighborhood Latitude                 43.6659
# Neighborhood Longitude               -79.3832
# Venue                             Chick-Fil-A
# Venue Latitude                        43.6695
# Venue Longitude                      -79.3862
# Venue Category            American Restaurant
# Name: 2182, dtype: object
# Borough                     East Toronto
# Neighborhood Latitude            43.6627
# Neighborhood Longitude          -79.3216
# Venue                     The Green Wood
# Venue Latitude                   43.6647
# Venue Longitude                 -79.3241
# Venue Category                Restaurant
# Name: 2188, dtype: object
# Borough                           East Toronto
# Neighborhood Latitude                  43.6627
# Neighborhood Longitude                -79.3216
# Venue                              Chick-n-Joy
# Venue Latitude                         43.6652
# Venue Longitude                       -79.3214
# Venue Category            Fast Food Restaurant
# Name: 2190, dtype: object
# Borough                              Etobicoke
# Neighborhood Latitude                  43.6288
# Neighborhood Longitude                 -79.521
# Venue                               McDonald's
# Venue Latitude                         43.6301
# Venue Longitude                       -79.5179
# Venue Category            Fast Food Restaurant
# Name: 2207, dtype: object

# %%
b1=[]
b2=[]
b3=[]
b4=[]
b5=[]
b6=[]
b7=[]
 
for i in range(len(toronto_df)):
    a="Restaurant"
    if a in toronto_df.loc[i,'Venue Category']:
        a1 = toronto_df.loc[i,'Borough']
        a2 = toronto_df.loc[i,'Neighborhood Latitude']
        a3 = toronto_df.loc[i,'Neighborhood Longitude']
        a4 = toronto_df.loc[i,'Venue']
        a5 = toronto_df.loc[i,'Venue Latitude']
        a6 = toronto_df.loc[i,'Venue Longitude']
        a7 = toronto_df.loc[i,'Venue Category']
        
        b1.append(a1)
        b2.append(a2)
        b3.append(a3)
        b4.append(a4)
        b5.append(a5)
        b6.append(a6)
        b7.append(a7)
        
toronto_df_bo=pd.DataFrame(columns=['Borough',
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category'])
 
toronto_df_bo['Borough']=b1
toronto_df_bo['Neighborhood Latitude']=b2
toronto_df_bo['Neighborhood Longitude']=b3
toronto_df_bo[ 'Venue']=b4
toronto_df_bo['Venue Latitude']=b5
toronto_df_bo['Venue Longitude']=b6
toronto_df_bo['Venue Category']=b7

toronto_df_bo.head()
# Out:
#             Borough  Neighborhood Latitude  Neighborhood Longitude  \
# 0        North York              43.725882              -79.315572
# 1        North York              43.725882              -79.315572
# 2  Downtown Toronto              43.654260              -79.360636
# 3  Downtown Toronto              43.654260              -79.360636
# 4  Downtown Toronto              43.654260              -79.360636
#
#                         Venue  Venue Latitude  Venue Longitude  \
# 0                   Portugril       43.725819       -79.312785
# 1                    The Frig       43.727051       -79.317418
# 2              Impact Kitchen       43.656369       -79.356980
# 3                   El Catrin       43.650601       -79.358920
# 4  Cluny Bistro & Boulangerie       43.650565       -79.357843
#
#           Venue Category
# 0  Portuguese Restaurant
# 1      French Restaurant
# 2             Restaurant
# 3     Mexican Restaurant
# 4      French Restaurant

# %%
for i in range(len(toronto_df_neigh)):
    a="Restaurant"
    if a in toronto_df_neigh.loc[i,'Venue Category']:
        print(toronto_df_neigh.loc[i,:])
# Out:
# Neighborhood                   Victoria Village
# Neighborhood Latitude                   43.7259
# Neighborhood Longitude                 -79.3156
# Venue                                 Portugril
# Venue Latitude                          43.7258
# Venue Longitude                        -79.3128
# Venue Category            Portuguese Restaurant
# Name: 5, dtype: object
# Neighborhood               Victoria Village
# Neighborhood Latitude               43.7259
# Neighborhood Longitude             -79.3156
# Venue                              The Frig
# Venue Latitude                      43.7271
# Venue Longitude                    -79.3174
# Venue Category            French Restaurant
# Name: 6, dtype: object
# Neighborhood              Harbourfront,Regent Park
# Neighborhood Latitude                      43.6543
# Neighborhood Longitude                    -79.3606
# Venue                               Impact Kitchen
# Venue Latitude                             43.6564
# Venue Longitude                            -79.357
# Venue Category                          Restaurant
# Name: 12, dtype: object
# Neighborhood              Harbourfront,Regent Park
# Neighborhood Latitude                      43.6543
# Neighborhood Longitude                    -79.3606
# Venue                                    El Catrin
# Venue Latitude                             43.6506
# Venue Longitude                           -79.3589
# Venue Category                  Mexican Restaurant
# Name: 29, dtype: object
# Neighborhood                Harbourfront,Regent Park
# Neighborhood Latitude                        43.6543
# Neighborhood Longitude                      -79.3606
# Venue                     Cluny Bistro & Boulangerie
# Venue Latitude                               43.6506
# Venue Longitude                             -79.3578
# Venue Category                     French Restaurant
# Name: 30, dtype: object
# Neighborhood              Harbourfront,Regent Park
# Neighborhood Latitude                      43.6543
# Neighborhood Longitude                    -79.3606
# Venue                             Cocina Economica
# Venue Latitude                              43.655
# Venue Longitude                           -79.3657
# Venue Category                  Mexican Restaurant
# Name: 33, dtype: object
# Neighborhood              Harbourfront,Regent Park
# Neighborhood Latitude                      43.6543
# Neighborhood Longitude                    -79.3606
# Venue                             Souvlaki Express
# Venue Latitude                             43.6556
# Venue Longitude                           -79.3644
# Venue Category                    Greek Restaurant
# Name: 45, dtype: object
# Neighborhood              Harbourfront,Regent Park
# Neighborhood Latitude                      43.6543
# Neighborhood Longitude                    -79.3606
# Venue                                       Archeo
# Venue Latitude                             43.6507
# Venue Longitude                           -79.3594
# Venue Category                  Italian Restaurant
# Name: 47, dtype: object
# Neighborhood              Harbourfront,Regent Park
# Neighborhood Latitude                      43.6543
# Neighborhood Longitude                    -79.3606
# Venue                                  Flame Shack
# Venue Latitude                             43.6568
# Venue Longitude                           -79.3589
# Venue Category                          Restaurant
# Name: 52, dtype: object
# Neighborhood              Lawrence Heights,Lawrence Manor
# Neighborhood Latitude                             43.7185
# Neighborhood Longitude                           -79.4648
# Venue                      Lac Vien Vietnamese Restaurant
# Venue Latitude                                    43.7213
# Venue Longitude                                  -79.4685
# Venue Category                      Vietnamese Restaurant
# Name: 58, dtype: object
# Neighborhood                     Rouge,Malvern
# Neighborhood Latitude                  43.8067
# Neighborhood Longitude                -79.1944
# Venue                                  Wendy's
# Venue Latitude                         43.8074
# Venue Longitude                       -79.1991
# Venue Category            Fast Food Restaurant
# Name: 70, dtype: object
# Neighborhood                   Don Mills North
# Neighborhood Latitude                  43.7459
# Neighborhood Longitude                -79.3522
# Venue                             Island Foods
# Venue Latitude                         43.7459
# Venue Longitude                        -79.346
# Venue Category            Caribbean Restaurant
# Name: 73, dtype: object
# Neighborhood                  Don Mills North
# Neighborhood Latitude                 43.7459
# Neighborhood Longitude               -79.3522
# Venue                             Gonoe Sushi
# Venue Latitude                        43.7457
# Venue Longitude                       -79.346
# Venue Category            Japanese Restaurant
# Name: 75, dtype: object
# Neighborhood              Woodbine Gardens,Parkview Hill
# Neighborhood Latitude                            43.7064
# Neighborhood Longitude                          -79.3099
# Venue                                           Harvey's
# Venue Latitude                                   43.7107
# Venue Longitude                                 -79.3088
# Venue Category                      Fast Food Restaurant
# Name: 81, dtype: object
# Neighborhood              Woodbine Gardens,Parkview Hill
# Neighborhood Latitude                            43.7064
# Neighborhood Longitude                          -79.3099
# Venue                                           Harvey's
# Venue Latitude                                   43.7081
# Venue Longitude                                 -79.3141
# Venue Category                      Fast Food Restaurant
# Name: 85, dtype: object
# Neighborhood                      Ryerson,Garden District
# Neighborhood Latitude                             43.6572
# Neighborhood Longitude                           -79.3789
# Venue                     Hokkaido Ramen Santouka らーめん山頭火
# Venue Latitude                                    43.6564
# Venue Longitude                                  -79.3776
# Venue Category                           Ramen Restaurant
# Name: 95, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                                  Salad King
# Venue Latitude                            43.6576
# Venue Longitude                          -79.3816
# Venue Category                    Thai Restaurant
# Name: 96, dtype: object
# Neighborhood                    Ryerson,Garden District
# Neighborhood Latitude                           43.6572
# Neighborhood Longitude                         -79.3789
# Venue                                   Urban Herbivore
# Venue Latitude                                   43.655
# Venue Longitude                                -79.3809
# Venue Category            Vegetarian / Vegan Restaurant
# Name: 105, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                                        JOEY
# Venue Latitude                            43.6561
# Venue Longitude                          -79.3819
# Venue Category                American Restaurant
# Name: 108, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                      Kinka Izakaya Original
# Venue Latitude                            43.6606
# Venue Longitude                          -79.3789
# Venue Category                Japanese Restaurant
# Name: 113, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                             Crepe Delicious
# Venue Latitude                            43.6545
# Venue Longitude                          -79.3809
# Venue Category               Fast Food Restaurant
# Name: 117, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                                Kinton Ramen
# Venue Latitude                            43.6606
# Venue Longitude                          -79.3789
# Venue Category                   Ramen Restaurant
# Name: 119, dtype: object
# Neighborhood                Ryerson,Garden District
# Neighborhood Latitude                       43.6572
# Neighborhood Longitude                     -79.3789
# Venue                                 Kabul Express
# Venue Latitude                              43.6567
# Venue Longitude                            -79.3766
# Venue Category            Middle Eastern Restaurant
# Name: 122, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                                  Milestones
# Venue Latitude                            43.6563
# Venue Longitude                          -79.3808
# Venue Category               Fast Food Restaurant
# Name: 125, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                      Chipotle Mexican Grill
# Venue Latitude                            43.6569
# Venue Longitude                          -79.3809
# Venue Category                 Mexican Restaurant
# Name: 130, dtype: object
# Neighborhood                       Ryerson,Garden District
# Neighborhood Latitude                              43.6572
# Neighborhood Longitude                            -79.3789
# Venue                     Scaddabush Italian Kitchen & Bar
# Venue Latitude                                     43.6589
# Venue Longitude                                   -79.3829
# Venue Category                          Italian Restaurant
# Name: 133, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                                 Red Lobster
# Venue Latitude                            43.6563
# Venue Longitude                          -79.3836
# Venue Category                 Seafood Restaurant
# Name: 134, dtype: object
# Neighborhood                 Ryerson,Garden District
# Neighborhood Latitude                        43.6572
# Neighborhood Longitude                      -79.3789
# Venue                        The Elm Tree Restaurant
# Venue Latitude                               43.6574
# Venue Longitude                             -79.3838
# Venue Category            Modern European Restaurant
# Name: 136, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                          Trattoria Mercatto
# Venue Latitude                            43.6545
# Venue Longitude                           -79.381
# Venue Category                 Italian Restaurant
# Name: 138, dtype: object
# Neighborhood                Ryerson,Garden District
# Neighborhood Latitude                       43.6572
# Neighborhood Longitude                     -79.3789
# Venue                          Paramount Fine Foods
# Venue Latitude                               43.655
# Venue Longitude                            -79.3802
# Venue Category            Middle Eastern Restaurant
# Name: 139, dtype: object
# Neighborhood               Ryerson,Garden District
# Neighborhood Latitude                      43.6572
# Neighborhood Longitude                    -79.3789
# Venue                     Jack Astor's Bar & Grill
# Venue Latitude                              43.656
# Venue Longitude                           -79.3803
# Venue Category                          Restaurant
# Name: 143, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                           Bourbon St. Grill
# Venue Latitude                            43.6551
# Venue Longitude                          -79.3808
# Venue Category               Fast Food Restaurant
# Name: 145, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                      GB Hand-Pulled Noodles
# Venue Latitude                            43.6564
# Venue Longitude                          -79.3838
# Venue Category                 Chinese Restaurant
# Name: 159, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                                 Ethiopiques
# Venue Latitude                            43.6565
# Venue Longitude                          -79.3771
# Venue Category               Ethiopian Restaurant
# Name: 166, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                                     Katsuya
# Venue Latitude                            43.6599
# Venue Longitude                          -79.3788
# Venue Category                Japanese Restaurant
# Name: 175, dtype: object
# Neighborhood              Ryerson,Garden District
# Neighborhood Latitude                     43.6572
# Neighborhood Longitude                   -79.3789
# Venue                             Fine Asian Bowl
# Venue Latitude                            43.6553
# Venue Longitude                          -79.3803
# Venue Category              Vietnamese Restaurant
# Name: 182, dtype: object
# Neighborhood                            Glencairn
# Neighborhood Latitude                     43.7096
# Neighborhood Longitude                   -79.4451
# Venue                     Miyako Sushi Restaurant
# Venue Latitude                            43.7091
# Venue Longitude                          -79.4439
# Venue Category                Japanese Restaurant
# Name: 187, dtype: object
# Neighborhood                     Glencairn
# Neighborhood Latitude              43.7096
# Neighborhood Longitude            -79.4451
# Venue                         Kokoro Sushi
# Venue Latitude                      43.709
# Venue Longitude                   -79.4441
# Venue Category            Sushi Restaurant
# Name: 189, dtype: object
# Neighborhood              Flemingdon Park,Don Mills South
# Neighborhood Latitude                             43.7259
# Neighborhood Longitude                           -79.3409
# Venue                                  Sorento Restaurant
# Venue Latitude                                    43.7266
# Venue Longitude                                   -79.342
# Venue Category                         Italian Restaurant
# Name: 194, dtype: object
# Neighborhood              Flemingdon Park,Don Mills South
# Neighborhood Latitude                             43.7259
# Neighborhood Longitude                           -79.3409
# Venue                     Swiss Chalet Rotisserie & Grill
# Venue Latitude                                    43.7267
# Venue Longitude                                  -79.3414
# Venue Category                                 Restaurant
# Name: 197, dtype: object
# Neighborhood              Flemingdon Park,Don Mills South
# Neighborhood Latitude                             43.7259
# Neighborhood Longitude                           -79.3409
# Venue                                   Memories of Japan
# Venue Latitude                                    43.7273
# Venue Longitude                                  -79.3414
# Venue Category                        Japanese Restaurant
# Name: 200, dtype: object
# Neighborhood              Flemingdon Park,Don Mills South
# Neighborhood Latitude                             43.7259
# Neighborhood Longitude                           -79.3409
# Venue                        Genghis Khan Mongolian Grill
# Venue Latitude                                    43.7269
# Venue Longitude                                  -79.3412
# Venue Category                           Asian Restaurant
# Name: 203, dtype: object
# Neighborhood              Flemingdon Park,Don Mills South
# Neighborhood Latitude                             43.7259
# Neighborhood Longitude                           -79.3409
# Venue                                        Asian Legend
# Venue Latitude                                    43.7266
# Venue Longitude                                  -79.3422
# Venue Category                         Dim Sum Restaurant
# Name: 205, dtype: object
# Neighborhood              Flemingdon Park,Don Mills South
# Neighborhood Latitude                             43.7259
# Neighborhood Longitude                           -79.3409
# Venue                                    Congee Star 帝王名粥
# Venue Latitude                                    43.7266
# Venue Longitude                                  -79.3418
# Venue Category                         Chinese Restaurant
# Name: 208, dtype: object
# Neighborhood              Flemingdon Park,Don Mills South
# Neighborhood Latitude                             43.7259
# Neighborhood Longitude                           -79.3409
# Venue                                            Harvey's
# Venue Latitude                                    43.7266
# Venue Longitude                                   -79.341
# Venue Category                       Fast Food Restaurant
# Name: 211, dtype: object
# Neighborhood              Flemingdon Park,Don Mills South
# Neighborhood Latitude                             43.7259
# Neighborhood Longitude                           -79.3409
# Venue                                         Pho 88 發發餐廳
# Venue Latitude                                    43.7266
# Venue Longitude                                  -79.3423
# Venue Category                           Asian Restaurant
# Name: 212, dtype: object
# Neighborhood                     St. James Town
# Neighborhood Latitude                   43.6515
# Neighborhood Longitude                 -79.3754
# Venue                     Gyu-Kaku Japanese BBQ
# Venue Latitude                          43.6514
# Venue Longitude                         -79.375
# Venue Category              Japanese Restaurant
# Name: 223, dtype: object
# Neighborhood                 St. James Town
# Neighborhood Latitude               43.6515
# Neighborhood Longitude             -79.3754
# Venue                     GEORGE Restaurant
# Venue Latitude                      43.6533
# Venue Longitude                    -79.3744
# Venue Category                   Restaurant
# Name: 224, dtype: object
# Neighborhood                  St. James Town
# Neighborhood Latitude                43.6515
# Neighborhood Longitude              -79.3754
# Venue                                Terroni
# Venue Latitude                       43.6509
# Venue Longitude                     -79.3756
# Venue Category            Italian Restaurant
# Name: 226, dtype: object
# Neighborhood                         St. James Town
# Neighborhood Latitude                       43.6515
# Neighborhood Longitude                     -79.3754
# Venue                                 Mystic Muffin
# Venue Latitude                              43.6525
# Venue Longitude                            -79.3727
# Venue Category            Middle Eastern Restaurant
# Name: 231, dtype: object
# Neighborhood                   St. James Town
# Neighborhood Latitude                 43.6515
# Neighborhood Longitude               -79.3754
# Venue                                    NAMI
# Venue Latitude                        43.6509
# Venue Longitude                      -79.3759
# Venue Category            Japanese Restaurant
# Name: 233, dtype: object
# Neighborhood                   St. James Town
# Neighborhood Latitude                 43.6515
# Neighborhood Longitude               -79.3754
# Venue                        Richmond Station
# Venue Latitude                        43.6516
# Venue Longitude                      -79.3793
# Venue Category            American Restaurant
# Name: 239, dtype: object
# Neighborhood              St. James Town
# Neighborhood Latitude            43.6515
# Neighborhood Longitude          -79.3754
# Venue                     The Carbon Bar
# Venue Latitude                   43.6534
# Venue Longitude                  -79.375
# Venue Category                Restaurant
# Name: 240, dtype: object
# Neighborhood                  St. James Town
# Neighborhood Latitude                43.6515
# Neighborhood Longitude              -79.3754
# Venue                                Carisma
# Venue Latitude                       43.6496
# Venue Longitude                     -79.3754
# Venue Category            Italian Restaurant
# Name: 245, dtype: object
# Neighborhood                     St. James Town
# Neighborhood Latitude                   43.6515
# Neighborhood Longitude                 -79.3754
# Venue                     La Bettola Di Terroni
# Venue Latitude                           43.652
# Venue Longitude                        -79.3781
# Venue Category               Italian Restaurant
# Name: 248, dtype: object
# Neighborhood               St. James Town
# Neighborhood Latitude             43.6515
# Neighborhood Longitude           -79.3754
# Venue                           Sukhothai
# Venue Latitude                    43.6485
# Venue Longitude                  -79.3745
# Venue Category            Thai Restaurant
# Name: 251, dtype: object
# Neighborhood                       St. James Town
# Neighborhood Latitude                     43.6515
# Neighborhood Longitude                   -79.3754
# Venue                                   The Chase
# Venue Latitude                             43.651
# Venue Longitude                          -79.3794
# Venue Category            New American Restaurant
# Name: 253, dtype: object
# Neighborhood                         St. James Town
# Neighborhood Latitude                       43.6515
# Neighborhood Longitude                     -79.3754
# Venue                                          Leña
# Venue Latitude                              43.6518
# Venue Longitude                             -79.379
# Venue Category            Latin American Restaurant
# Name: 260, dtype: object
# Neighborhood                     St. James Town
# Neighborhood Latitude                   43.6515
# Neighborhood Longitude                 -79.3754
# Venue                     Victoria's Restaurant
# Venue Latitude                          43.6493
# Venue Longitude                        -79.3764
# Venue Category                       Restaurant
# Name: 262, dtype: object
# Neighborhood                             St. James Town
# Neighborhood Latitude                           43.6515
# Neighborhood Longitude                         -79.3754
# Venue                                    Fresh On Front
# Venue Latitude                                  43.6478
# Venue Longitude                                -79.3745
# Venue Category            Vegetarian / Vegan Restaurant
# Name: 273, dtype: object
# Neighborhood                   St. James Town
# Neighborhood Latitude                 43.6515
# Neighborhood Longitude               -79.3754
# Venue                     Market Street Catch
# Venue Latitude                        43.6485
# Venue Longitude                      -79.3718
# Venue Category             Seafood Restaurant
# Name: 274, dtype: object
# Neighborhood                               St. James Town
# Neighborhood Latitude                             43.6515
# Neighborhood Longitude                           -79.3754
# Venue                     The Works Gourmet Burger Bistro
# Venue Latitude                                    43.6487
# Venue Longitude                                  -79.3741
# Venue Category                                 Restaurant
# Name: 286, dtype: object
# Neighborhood                  St. James Town
# Neighborhood Latitude                43.6515
# Neighborhood Longitude              -79.3754
# Venue                      Buster's Sea Cove
# Venue Latitude                       43.6485
# Venue Longitude                     -79.3715
# Venue Category            Seafood Restaurant
# Name: 291, dtype: object
# Neighborhood                   St. James Town
# Neighborhood Latitude                 43.6515
# Neighborhood Longitude               -79.3754
# Venue                           The Gabardine
# Venue Latitude                         43.651
# Venue Longitude                      -79.3812
# Venue Category            American Restaurant
# Name: 300, dtype: object
# Neighborhood                       St. James Town
# Neighborhood Latitude                     43.6515
# Neighborhood Longitude                   -79.3754
# Venue                              Loaded Pierogi
# Venue Latitude                             43.648
# Venue Longitude                          -79.3734
# Venue Category            Comfort Food Restaurant
# Name: 304, dtype: object
# Neighborhood                 St. James Town
# Neighborhood Latitude               43.6515
# Neighborhood Longitude             -79.3754
# Venue                       Schnitzel Queen
# Venue Latitude                      43.6542
# Venue Longitude                    -79.3705
# Venue Category            German Restaurant
# Name: 307, dtype: object
# Neighborhood                 St. James Town
# Neighborhood Latitude               43.6515
# Neighborhood Longitude             -79.3754
# Venue                         Biff's Bistro
# Venue Latitude                      43.6471
# Venue Longitude                    -79.3763
# Venue Category            French Restaurant
# Name: 308, dtype: object
# Neighborhood              St. James Town
# Neighborhood Latitude            43.6515
# Neighborhood Longitude          -79.3754
# Venue                            Bannock
# Venue Latitude                   43.6521
# Venue Longitude                 -79.3812
# Venue Category                Restaurant
# Name: 311, dtype: object
# Neighborhood                             St. James Town
# Neighborhood Latitude                           43.6515
# Neighborhood Longitude                         -79.3754
# Venue                     Vagabondo Ristorante & Lounge
# Venue Latitude                                  43.6482
# Venue Longitude                                -79.3753
# Venue Category                       Italian Restaurant
# Name: 315, dtype: object
# Neighborhood                    St. James Town
# Neighborhood Latitude                  43.6515
# Neighborhood Longitude                -79.3754
# Venue                                   B.GOOD
# Venue Latitude                         43.6496
# Venue Longitude                       -79.3712
# Venue Category            Fast Food Restaurant
# Name: 318, dtype: object
# Neighborhood                  St. James Town
# Neighborhood Latitude                43.6515
# Neighborhood Longitude              -79.3754
# Venue                               Mercatto
# Venue Latitude                       43.6502
# Venue Longitude                     -79.3808
# Venue Category            Italian Restaurant
# Name: 319, dtype: object
# Neighborhood              Guildwood,Morningside,West Hill
# Neighborhood Latitude                             43.7636
# Neighborhood Longitude                           -79.1887
# Venue                                    Big Bite Burrito
# Venue Latitude                                    43.7663
# Venue Longitude                                  -79.1907
# Venue Category                         Mexican Restaurant
# Name: 336, dtype: object
# Neighborhood                                Berczy Park
# Neighborhood Latitude                           43.6448
# Neighborhood Longitude                         -79.3733
# Venue                                    Fresh On Front
# Venue Latitude                                  43.6478
# Venue Longitude                                -79.3745
# Venue Category            Vegetarian / Vegan Restaurant
# Name: 349, dtype: object
# Neighborhood                    Berczy Park
# Neighborhood Latitude               43.6448
# Neighborhood Longitude             -79.3733
# Venue                         Biff's Bistro
# Venue Latitude                      43.6471
# Venue Longitude                    -79.3763
# Venue Category            French Restaurant
# Name: 355, dtype: object
# Neighborhood                  Berczy Park
# Neighborhood Latitude             43.6448
# Neighborhood Longitude           -79.3733
# Venue                           Sukhothai
# Venue Latitude                    43.6485
# Venue Longitude                  -79.3745
# Venue Category            Thai Restaurant
# Name: 356, dtype: object
# Neighborhood                      Berczy Park
# Neighborhood Latitude                 43.6448
# Neighborhood Longitude               -79.3733
# Venue                     Market Street Catch
# Venue Latitude                        43.6485
# Venue Longitude                      -79.3718
# Venue Category             Seafood Restaurant
# Name: 357, dtype: object
# Neighborhood                     Berczy Park
# Neighborhood Latitude                43.6448
# Neighborhood Longitude              -79.3733
# Venue                      Buster's Sea Cove
# Venue Latitude                       43.6485
# Venue Longitude                     -79.3715
# Venue Category            Seafood Restaurant
# Name: 366, dtype: object
# Neighborhood                          Berczy Park
# Neighborhood Latitude                     43.6448
# Neighborhood Longitude                   -79.3733
# Venue                              Loaded Pierogi
# Venue Latitude                             43.648
# Venue Longitude                          -79.3734
# Venue Category            Comfort Food Restaurant
# Name: 371, dtype: object
# Neighborhood                                 Berczy Park
# Neighborhood Latitude                            43.6448
# Neighborhood Longitude                          -79.3733
# Venue                     Alexandro's World Famous Gyros
# Venue Latitude                                   43.6417
# Venue Longitude                                 -79.3752
# Venue Category                          Greek Restaurant
# Name: 377, dtype: object
# Neighborhood                       Berczy Park
# Neighborhood Latitude                  43.6448
# Neighborhood Longitude                -79.3733
# Venue                     Bier Markt Esplanade
# Venue Latitude                         43.6472
# Venue Longitude                       -79.3739
# Venue Category              Belgian Restaurant
# Name: 382, dtype: object
# Neighborhood                                  Berczy Park
# Neighborhood Latitude                             43.6448
# Neighborhood Longitude                           -79.3733
# Venue                     The Works Gourmet Burger Bistro
# Venue Latitude                                    43.6487
# Venue Longitude                                  -79.3741
# Venue Category                                 Restaurant
# Name: 393, dtype: object
# Neighborhood                                Berczy Park
# Neighborhood Latitude                           43.6448
# Neighborhood Longitude                         -79.3733
# Venue                     Vagabondo Ristorante & Lounge
# Venue Latitude                                  43.6482
# Venue Longitude                                -79.3753
# Venue Category                       Italian Restaurant
# Name: 397, dtype: object
# Neighborhood                       Berczy Park
# Neighborhood Latitude                  43.6448
# Neighborhood Longitude                -79.3733
# Venue                     Bindia Indian Bistro
# Venue Latitude                         43.6486
# Venue Longitude                       -79.3718
# Venue Category               Indian Restaurant
# Name: 401, dtype: object
# Neighborhood               Caledonia-Fairbanks
# Neighborhood Latitude                   43.689
# Neighborhood Longitude                -79.4535
# Venue                                      KFC
# Venue Latitude                         43.6906
# Venue Longitude                       -79.4563
# Venue Category            Fast Food Restaurant
# Name: 403, dtype: object
# Neighborhood                          Woburn
# Neighborhood Latitude                 43.771
# Neighborhood Longitude              -79.2169
# Venue                     Korean Grill House
# Venue Latitude                       43.7708
# Venue Longitude                     -79.2145
# Venue Category             Korean Restaurant
# Name: 410, dtype: object
# Neighborhood                      Leaside
# Neighborhood Latitude             43.7091
# Neighborhood Longitude           -79.3635
# Venue                     The Leaside Pub
# Venue Latitude                    43.7104
# Venue Longitude                  -79.3635
# Venue Category                 Restaurant
# Name: 416, dtype: object
# Neighborhood                                  Leaside
# Neighborhood Latitude                         43.7091
# Neighborhood Longitude                       -79.3635
# Venue                     Kintako Japanese Restaurant
# Venue Latitude                                43.7116
# Venue Longitude                               -79.364
# Venue Category                       Sushi Restaurant
# Name: 421, dtype: object
# Neighborhood                                        Leaside
# Neighborhood Latitude                               43.7091
# Neighborhood Longitude                             -79.3635
# Venue                     Mucho Burrito Fresh Mexican Grill
# Venue Latitude                                      43.7067
# Venue Longitude                                    -79.3617
# Venue Category                           Mexican Restaurant
# Name: 439, dtype: object
# Neighborhood              Central Bay Street
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                               Mercatto
# Venue Latitude                       43.6604
# Venue Longitude                     -79.3877
# Venue Category            Italian Restaurant
# Name: 449, dtype: object
# Neighborhood                      Central Bay Street
# Neighborhood Latitude                         43.658
# Neighborhood Longitude                      -79.3874
# Venue                        The Elm Tree Restaurant
# Venue Latitude                               43.6574
# Venue Longitude                             -79.3838
# Venue Category            Modern European Restaurant
# Name: 450, dtype: object
# Neighborhood              Central Bay Street
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                                Japango
# Venue Latitude                       43.6553
# Venue Longitude                     -79.3852
# Venue Category              Sushi Restaurant
# Name: 453, dtype: object
# Neighborhood              Central Bay Street
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                     Sansotei Ramen 三草亭
# Venue Latitude                       43.6552
# Venue Longitude                     -79.3865
# Venue Category              Ramen Restaurant
# Name: 454, dtype: object
# Neighborhood              Central Bay Street
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                            Red Lobster
# Venue Latitude                       43.6563
# Venue Longitude                     -79.3836
# Venue Category            Seafood Restaurant
# Name: 458, dtype: object
# Neighborhood               Central Bay Street
# Neighborhood Latitude                  43.658
# Neighborhood Longitude               -79.3874
# Venue                              Rolltation
# Venue Latitude                        43.6549
# Venue Longitude                      -79.3874
# Venue Category            Japanese Restaurant
# Name: 463, dtype: object
# Neighborhood                            Central Bay Street
# Neighborhood Latitude                               43.658
# Neighborhood Longitude                            -79.3874
# Venue                     Scaddabush Italian Kitchen & Bar
# Venue Latitude                                     43.6589
# Venue Longitude                                   -79.3829
# Venue Category                          Italian Restaurant
# Name: 464, dtype: object
# Neighborhood                 Central Bay Street
# Neighborhood Latitude                    43.658
# Neighborhood Longitude                 -79.3874
# Venue                                   Nando's
# Venue Latitude                          43.6616
# Venue Longitude                        -79.3861
# Venue Category            Portuguese Restaurant
# Name: 472, dtype: object
# Neighborhood                         Central Bay Street
# Neighborhood Latitude                            43.658
# Neighborhood Longitude                         -79.3874
# Venue                                  Vegetarian Haven
# Venue Latitude                                   43.656
# Venue Longitude                                -79.3928
# Venue Category            Vegetarian / Vegan Restaurant
# Name: 476, dtype: object
# Neighborhood              Central Bay Street
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                             Salad King
# Venue Latitude                       43.6576
# Venue Longitude                     -79.3816
# Venue Category               Thai Restaurant
# Name: 479, dtype: object
# Neighborhood                     Central Bay Street
# Neighborhood Latitude                        43.658
# Neighborhood Longitude                     -79.3874
# Venue                                    Ali Baba's
# Venue Latitude                              43.6549
# Venue Longitude                            -79.3872
# Venue Category            Middle Eastern Restaurant
# Name: 480, dtype: object
# Neighborhood                  Central Bay Street
# Neighborhood Latitude                     43.658
# Neighborhood Longitude                  -79.3874
# Venue                     GB Hand-Pulled Noodles
# Venue Latitude                           43.6564
# Venue Longitude                         -79.3838
# Venue Category                Chinese Restaurant
# Name: 483, dtype: object
# Neighborhood              Central Bay Street
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                        Lebanon Express
# Venue Latitude                        43.661
# Venue Longitude                      -79.383
# Venue Category            Falafel Restaurant
# Name: 488, dtype: object
# Neighborhood               Central Bay Street
# Neighborhood Latitude                  43.658
# Neighborhood Longitude               -79.3874
# Venue                                    JOEY
# Venue Latitude                        43.6561
# Venue Longitude                      -79.3819
# Venue Category            American Restaurant
# Name: 490, dtype: object
# Neighborhood              Central Bay Street
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                          Sambuca Grill
# Venue Latitude                       43.6561
# Venue Longitude                     -79.3929
# Venue Category            Italian Restaurant
# Name: 497, dtype: object
# Neighborhood              Central Bay Street
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                            Midi Bistro
# Venue Latitude                       43.6559
# Venue Longitude                     -79.3921
# Venue Category             French Restaurant
# Name: 503, dtype: object
# Neighborhood              Central Bay Street
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                        Colaba Junction
# Venue Latitude                       43.6609
# Venue Longitude                     -79.3856
# Venue Category             Indian Restaurant
# Name: 513, dtype: object
# Neighborhood               Central Bay Street
# Neighborhood Latitude                  43.658
# Neighborhood Longitude               -79.3874
# Venue                                    Omai
# Venue Latitude                         43.656
# Venue Longitude                      -79.3925
# Venue Category            Japanese Restaurant
# Name: 518, dtype: object
# Neighborhood              Central Bay Street
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                                  Tosto
# Venue Latitude                       43.6612
# Venue Longitude                     -79.3864
# Venue Category            Italian Restaurant
# Name: 522, dtype: object
# Neighborhood              Central Bay Street
# Neighborhood Latitude                 43.658
# Neighborhood Longitude              -79.3874
# Venue                              Mo'Ramyun
# Venue Latitude                       43.6561
# Venue Longitude                     -79.3923
# Venue Category             Korean Restaurant
# Name: 527, dtype: object
# Neighborhood                                      Central Bay Street
# Neighborhood Latitude                                         43.658
# Neighborhood Longitude                                      -79.3874
# Venue                     Just Falafel  . . . Redefining Street Food
# Venue Latitude                                               43.6618
# Venue Longitude                                             -79.3861
# Venue Category                              Mediterranean Restaurant
# Name: 528, dtype: object
# Neighborhood                        Christie
# Neighborhood Latitude                43.6695
# Neighborhood Longitude              -79.4226
# Venue                         Vinny’s Panini
# Venue Latitude                       43.6707
# Venue Longitude                     -79.4261
# Venue Category            Italian Restaurant
# Name: 533, dtype: object
# Neighborhood                Christie
# Neighborhood Latitude        43.6695
# Neighborhood Longitude      -79.4226
# Venue                     Actinolite
# Venue Latitude               43.6679
# Venue Longitude             -79.4281
# Venue Category            Restaurant
# Name: 536, dtype: object
# Neighborhood                        Cedarbrae
# Neighborhood Latitude                 43.7731
# Neighborhood Longitude               -79.2395
# Venue                     Federick Restaurant
# Venue Latitude                        43.7747
# Venue Longitude                      -79.2411
# Venue Category               Hakka Restaurant
# Name: 546, dtype: object
# Neighborhood                             Cedarbrae
# Neighborhood Latitude                      43.7731
# Neighborhood Longitude                    -79.2395
# Venue                     Drupati's Roti & Doubles
# Venue Latitude                             43.7752
# Venue Longitude                           -79.2417
# Venue Category                Caribbean Restaurant
# Name: 547, dtype: object
# Neighborhood                    Cedarbrae
# Neighborhood Latitude             43.7731
# Neighborhood Longitude           -79.2395
# Venue                         Thai One On
# Venue Latitude                    43.7745
# Venue Longitude                  -79.2413
# Venue Category            Thai Restaurant
# Name: 548, dtype: object
# Neighborhood                     Hillcrest Village
# Neighborhood Latitude                      43.8038
# Neighborhood Longitude                    -79.3635
# Venue                                 Villa Madina
# Venue Latitude                             43.8017
# Venue Longitude                           -79.3639
# Venue Category            Mediterranean Restaurant
# Name: 555, dtype: object
# Neighborhood              Bathurst Manor,Downsview North,Wilson Heights
# Neighborhood Latitude                                           43.7543
# Neighborhood Longitude                                         -79.4423
# Venue                                                        Bagel Plus
# Venue Latitude                                                  43.7554
# Venue Longitude                                                -79.4407
# Venue Category                                               Restaurant
# Name: 558, dtype: object
# Neighborhood              Bathurst Manor,Downsview North,Wilson Heights
# Neighborhood Latitude                                           43.7543
# Neighborhood Longitude                                         -79.4423
# Venue                                           Orly Restaurant & Grill
# Venue Latitude                                                  43.7545
# Venue Longitude                                                -79.4435
# Venue Category                                Middle Eastern Restaurant
# Name: 560, dtype: object
# Neighborhood              Bathurst Manor,Downsview North,Wilson Heights
# Neighborhood Latitude                                           43.7543
# Neighborhood Longitude                                         -79.4423
# Venue                                                       Dairy Queen
# Venue Latitude                                                  43.7557
# Venue Longitude                                                -79.4402
# Venue Category                                     Fast Food Restaurant
# Name: 563, dtype: object
# Neighborhood              Bathurst Manor,Downsview North,Wilson Heights
# Neighborhood Latitude                                           43.7543
# Neighborhood Longitude                                         -79.4423
# Venue                                                      Wakame Sushi
# Venue Latitude                                                  43.7554
# Venue Longitude                                                -79.4409
# Venue Category                                         Sushi Restaurant
# Name: 566, dtype: object
# Neighborhood                        Thorncliffe Park
# Neighborhood Latitude                        43.7054
# Neighborhood Longitude                      -79.3494
# Venue                     Iqbal Kebab & Sweet Centre
# Venue Latitude                               43.7059
# Venue Longitude                             -79.3515
# Venue Category                     Indian Restaurant
# Name: 577, dtype: object
# Neighborhood               Thorncliffe Park
# Neighborhood Latitude               43.7054
# Neighborhood Longitude             -79.3494
# Venue                          Hakka Garden
# Venue Latitude                      43.7046
# Venue Longitude                    -79.3498
# Venue Category            Indian Restaurant
# Name: 582, dtype: object
# Neighborhood                     Adelaide,King,Richmond
# Neighborhood Latitude                           43.6506
# Neighborhood Longitude                         -79.3846
# Venue                                         Rosalinda
# Venue Latitude                                  43.6503
# Venue Longitude                                -79.3852
# Venue Category            Vegetarian / Vegan Restaurant
# Name: 597, dtype: object
# Neighborhood              Adelaide,King,Richmond
# Neighborhood Latitude                    43.6506
# Neighborhood Longitude                  -79.3846
# Venue                         Bosk at Shangri-La
# Venue Latitude                            43.649
# Venue Longitude                         -79.3858
# Venue Category                  Asian Restaurant
# Name: 599, dtype: object
# Neighborhood              Adelaide,King,Richmond
# Neighborhood Latitude                    43.6506
# Neighborhood Longitude                  -79.3846
# Venue                           Estiatorio Volos
# Venue Latitude                           43.6503
# Venue Longitude                         -79.3845
# Venue Category                  Greek Restaurant
# Name: 601, dtype: object
# Neighborhood              Adelaide,King,Richmond
# Neighborhood Latitude                    43.6506
# Neighborhood Longitude                  -79.3846
# Venue                                Noodle King
# Venue Latitude                           43.6517
# Venue Longitude                          -79.383
# Venue Category                  Asian Restaurant
# Name: 603, dtype: object
# Neighborhood              Adelaide,King,Richmond
# Neighborhood Latitude                    43.6506
# Neighborhood Longitude                  -79.3846
# Venue                           Cactus Club Cafe
# Venue Latitude                           43.6496
# Venue Longitude                         -79.3817
# Venue Category               American Restaurant
# Name: 610, dtype: object
# Neighborhood                Adelaide,King,Richmond
# Neighborhood Latitude                      43.6506
# Neighborhood Longitude                    -79.3846
# Venue                     John & Sons Oyster House
# Venue Latitude                             43.6507
# ...
# Neighborhood Latitude                                   43.6484
# Neighborhood Longitude                                 -79.3823
# Venue                                                  Mercatto
# Venue Latitude                                          43.6502
# Venue Longitude                                        -79.3808
# Venue Category                               Italian Restaurant
# Name: 2061, dtype: object
# Neighborhood              First Canadian Place,Underground city
# Neighborhood Latitude                                   43.6484
# Neighborhood Longitude                                 -79.3823
# Venue                                               Noodle King
# Venue Latitude                                          43.6517
# Venue Longitude                                         -79.383
# Venue Category                                 Asian Restaurant
# Name: 2064, dtype: object
# Neighborhood              First Canadian Place,Underground city
# Neighborhood Latitude                                   43.6484
# Neighborhood Longitude                                 -79.3823
# Venue                                          Marché Mövenpick
# Venue Latitude                                          43.6473
# Venue Longitude                                        -79.3786
# Venue Category                                       Restaurant
# Name: 2066, dtype: object
# Neighborhood              First Canadian Place,Underground city
# Neighborhood Latitude                                   43.6484
# Neighborhood Longitude                                 -79.3823
# Venue                                  Fune Japanese Restaurant
# Venue Latitude                                          43.6485
# Venue Longitude                                        -79.3865
# Venue Category                              Japanese Restaurant
# Name: 2068, dtype: object
# Neighborhood              First Canadian Place,Underground city
# Neighborhood Latitude                                   43.6484
# Neighborhood Longitude                                 -79.3823
# Venue                                                Sweet Lulu
# Venue Latitude                                          43.6506
# Venue Longitude                                        -79.3812
# Venue Category                                 Asian Restaurant
# Name: 2071, dtype: object
# Neighborhood              First Canadian Place,Underground city
# Neighborhood Latitude                                   43.6484
# Neighborhood Longitude                                 -79.3823
# Venue                                                     Kojin
# Venue Latitude                                          43.6494
# Venue Longitude                                        -79.3861
# Venue Category                             Colombian Restaurant
# Name: 2075, dtype: object
# Neighborhood              First Canadian Place,Underground city
# Neighborhood Latitude                                   43.6484
# Neighborhood Longitude                                 -79.3823
# Venue                                               Thai Island
# Venue Latitude                                          43.6491
# Venue Longitude                                        -79.3838
# Venue Category                                  Thai Restaurant
# Name: 2077, dtype: object
# Neighborhood              First Canadian Place,Underground city
# Neighborhood Latitude                                   43.6484
# Neighborhood Longitude                                 -79.3823
# Venue                                            Byblos Toronto
# Venue Latitude                                          43.6476
# Venue Longitude                                        -79.3884
# Venue Category                         Mediterranean Restaurant
# Name: 2081, dtype: object
# Neighborhood              First Canadian Place,Underground city
# Neighborhood Latitude                                   43.6484
# Neighborhood Longitude                                 -79.3823
# Venue                              Copacabana Grilled Brazilian
# Venue Latitude                                          43.6483
# Venue Longitude                                        -79.3882
# Venue Category                             Brazilian Restaurant
# Name: 2084, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                         Storm Crow Manor
# Venue Latitude                         43.6668
# Venue Longitude                       -79.3816
# Venue Category                Theme Restaurant
# Name: 2097, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                       Sansotei Ramen 三草亭
# Venue Latitude                         43.6667
# Venue Longitude                       -79.3854
# Venue Category                Ramen Restaurant
# Name: 2101, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                                 Fabarnak
# Venue Latitude                         43.6664
# Venue Longitude                        -79.381
# Venue Category                      Restaurant
# Name: 2102, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                             Como En Casa
# Venue Latitude                         43.6652
# Venue Longitude                       -79.3848
# Venue Category              Mexican Restaurant
# Name: 2104, dtype: object
# Neighborhood                      Church and Wellesley
# Neighborhood Latitude                          43.6659
# Neighborhood Longitude                        -79.3832
# Venue                     Dal Moro's Fresh Pasta To Go
# Venue Latitude                                 43.6666
# Venue Longitude                               -79.3854
# Venue Category                      Italian Restaurant
# Name: 2119, dtype: object
# Neighborhood               Church and Wellesley
# Neighborhood Latitude                   43.6659
# Neighborhood Longitude                 -79.3832
# Venue                     Kothur Indian Cuisine
# Venue Latitude                          43.6679
# Venue Longitude                        -79.3857
# Venue Category                Indian Restaurant
# Name: 2120, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                                   Si Lom
# Venue Latitude                          43.665
# Venue Longitude                       -79.3807
# Venue Category                 Thai Restaurant
# Name: 2121, dtype: object
# Neighborhood               Church and Wellesley
# Neighborhood Latitude                   43.6659
# Neighborhood Longitude                 -79.3832
# Venue                                    Ginger
# Venue Latitude                          43.6654
# Venue Longitude                        -79.3808
# Venue Category            Vietnamese Restaurant
# Name: 2122, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                              Tokyo Sushi
# Venue Latitude                         43.6659
# Venue Longitude                        -79.387
# Venue Category                Sushi Restaurant
# Name: 2134, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                                     Wish
# Venue Latitude                         43.6688
# Venue Longitude                       -79.3857
# Venue Category                      Restaurant
# Name: 2137, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                           Loaded Pierogi
# Venue Latitude                         43.6647
# Venue Longitude                       -79.3806
# Venue Category               Polish Restaurant
# Name: 2141, dtype: object
# Neighborhood                  Church and Wellesley
# Neighborhood Latitude                      43.6659
# Neighborhood Longitude                    -79.3832
# Venue                     Tabriz Persian Cookhouse
# Venue Latitude                             43.6653
# Venue Longitude                           -79.3875
# Venue Category                  Persian Restaurant
# Name: 2144, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                               Wow! Sushi
# Venue Latitude                         43.6685
# Venue Longitude                       -79.3867
# Venue Category                Sushi Restaurant
# Name: 2150, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                               Kawa Sushi
# Venue Latitude                         43.6639
# Venue Longitude                       -79.3802
# Venue Category             Japanese Restaurant
# Name: 2152, dtype: object
# Neighborhood                  Church and Wellesley
# Neighborhood Latitude                      43.6659
# Neighborhood Longitude                    -79.3832
# Venue                                  Constantine
# Venue Latitude                             43.6688
# Venue Longitude                           -79.3853
# Venue Category            Mediterranean Restaurant
# Name: 2153, dtype: object
# Neighborhood                  Church and Wellesley
# Neighborhood Latitude                      43.6659
# Neighborhood Longitude                    -79.3832
# Venue                              The Salad House
# Venue Latitude                             43.6695
# Venue Longitude                           -79.3861
# Venue Category            Mediterranean Restaurant
# Name: 2155, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                             Naan & Kabob
# Venue Latitude                          43.669
# Venue Longitude                       -79.3862
# Venue Category               Afghan Restaurant
# Name: 2156, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                          The Blake House
# Venue Latitude                         43.6645
# Venue Longitude                       -79.3775
# Venue Category             American Restaurant
# Name: 2157, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                       The Captain's Boil
# Venue Latitude                         43.6624
# Venue Longitude                       -79.3835
# Venue Category              Seafood Restaurant
# Name: 2160, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                            Onnki Donburi
# Venue Latitude                         43.6698
# Venue Longitude                       -79.3846
# Venue Category             Japanese Restaurant
# Name: 2161, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                               Rolltation
# Venue Latitude                         43.6694
# Venue Longitude                       -79.3866
# Venue Category                Sushi Restaurant
# Name: 2162, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                      Ritz Caribbean Food
# Venue Latitude                         43.6695
# Venue Longitude                       -79.3865
# Venue Category            Caribbean Restaurant
# Name: 2164, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                     Okonomi House お好みハウス
# Venue Latitude                         43.6684
# Venue Longitude                       -79.3869
# Venue Category             Japanese Restaurant
# Name: 2165, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                                  O. Noir
# Venue Latitude                         43.6691
# Venue Longitude                       -79.3825
# Venue Category                      Restaurant
# Name: 2166, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                           Kokoni Izakaya
# Venue Latitude                         43.6642
# Venue Longitude                       -79.3803
# Venue Category             Japanese Restaurant
# Name: 2171, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                              Asahi Sushi
# Venue Latitude                         43.6699
# Venue Longitude                       -79.3829
# Venue Category                Sushi Restaurant
# Name: 2176, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                               A&W Canada
# Venue Latitude                         43.6664
# Venue Longitude                       -79.3782
# Venue Category            Fast Food Restaurant
# Name: 2178, dtype: object
# Neighborhood              Church and Wellesley
# Neighborhood Latitude                  43.6659
# Neighborhood Longitude                -79.3832
# Venue                              Chick-Fil-A
# Venue Latitude                         43.6695
# Venue Longitude                       -79.3862
# Venue Category             American Restaurant
# Name: 2182, dtype: object
# Neighborhood              Business Reply Mail Processing Centre 969 Eastern
# Neighborhood Latitude                                               43.6627
# Neighborhood Longitude                                             -79.3216
# Venue                                                        The Green Wood
# Venue Latitude                                                      43.6647
# Venue Longitude                                                    -79.3241
# Venue Category                                                   Restaurant
# Name: 2188, dtype: object
# Neighborhood              Business Reply Mail Processing Centre 969 Eastern
# Neighborhood Latitude                                               43.6627
# Neighborhood Longitude                                             -79.3216
# Venue                                                           Chick-n-Joy
# Venue Latitude                                                      43.6652
# Venue Longitude                                                    -79.3214
# Venue Category                                         Fast Food Restaurant
# Name: 2190, dtype: object
# Neighborhood              Kingsway Park South West,Mimico NW,The Queensw...
# Neighborhood Latitude                                               43.6288
# Neighborhood Longitude                                              -79.521
# Venue                                                            McDonald's
# Venue Latitude                                                      43.6301
# Venue Longitude                                                    -79.5179
# Venue Category                                         Fast Food Restaurant
# Name: 2207, dtype: object

# %%
b1=[]
b2=[]
b3=[]
b4=[]
b5=[]
b6=[]
b7=[]
 
for i in range(len(toronto_df_neigh)):
    a="Restaurant"
    if a in toronto_df_neigh.loc[i,'Venue Category']:
        a1 = toronto_df_neigh.loc[i,'Neighborhood']
        a2 = toronto_df_neigh.loc[i,'Neighborhood Latitude']
        a3 = toronto_df_neigh.loc[i,'Neighborhood Longitude']
        a4 = toronto_df_neigh.loc[i,'Venue']
        a5 = toronto_df_neigh.loc[i,'Venue Latitude']
        a6 = toronto_df_neigh.loc[i,'Venue Longitude']
        a7 = toronto_df_neigh.loc[i,'Venue Category']
        
        b1.append(a1)
        b2.append(a2)
        b3.append(a3)
        b4.append(a4)
        b5.append(a5)
        b6.append(a6)
        b7.append(a7)
        
toronto_df_neighborhood=pd.DataFrame(columns=['Neighborhood',
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category'])
 
toronto_df_neighborhood['Neighborhood']=b1
toronto_df_neighborhood['Neighborhood Latitude']=b2
toronto_df_neighborhood['Neighborhood Longitude']=b3
toronto_df_neighborhood[ 'Venue']=b4
toronto_df_neighborhood['Venue Latitude']=b5
toronto_df_neighborhood['Venue Longitude']=b6
toronto_df_neighborhood['Venue Category']=b7

toronto_df_neighborhood.head()
# Out:
#                Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0          Victoria Village              43.725882              -79.315572
# 1          Victoria Village              43.725882              -79.315572
# 2  Harbourfront,Regent Park              43.654260              -79.360636
# 3  Harbourfront,Regent Park              43.654260              -79.360636
# 4  Harbourfront,Regent Park              43.654260              -79.360636
#
#                         Venue  Venue Latitude  Venue Longitude  \
# 0                   Portugril       43.725819       -79.312785
# 1                    The Frig       43.727051       -79.317418
# 2              Impact Kitchen       43.656369       -79.356980
# 3                   El Catrin       43.650601       -79.358920
# 4  Cluny Bistro & Boulangerie       43.650565       -79.357843
#
#           Venue Category
# 0  Portuguese Restaurant
# 1      French Restaurant
# 2             Restaurant
# 3     Mexican Restaurant
# 4      French Restaurant

# %%
clr = "blue"
toronto_df_bo.groupby('Borough')['Venue'].count().plot.bar(figsize = (20,8), color = clr)
plt.title('Restaurant per Borough in Toronto', fontsize = 20)
plt.xlabel('Borough', fontsize = 12)
plt.ylabel('N. Neighborhoods', fontsize = 12)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
N_Neigh = 5 # top number for graphing all the same past 5
toronto_df_neighborhood.groupby('Neighborhood')['Venue'].count().nlargest(N_Neigh).plot.bar(figsize=(20,8), color=clr)
plt.title('Resturants per Neighborhood of Toronto', fontsize = 20)
plt.xlabel('Neighborhood', fontsize = 12)
plt.ylabel('Resturants', fontsize=12)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
toronto_rest = pd.merge(toronto_df_bo, toronto_df_neighborhood[['Neighborhood', 'Neighborhood Latitude', 'Neighborhood Longitude', 
                                                                   'Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category']], 
                   on = ('Neighborhood Latitude', 'Neighborhood Longitude', 'Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category'))
toronto_rest.head()
# Out:
#             Borough  Neighborhood Latitude  Neighborhood Longitude  \
# 0        North York              43.725882              -79.315572
# 1        North York              43.725882              -79.315572
# 2  Downtown Toronto              43.654260              -79.360636
# 3  Downtown Toronto              43.654260              -79.360636
# 4  Downtown Toronto              43.654260              -79.360636
#
#                         Venue  Venue Latitude  Venue Longitude  \
# 0                   Portugril       43.725819       -79.312785
# 1                    The Frig       43.727051       -79.317418
# 2              Impact Kitchen       43.656369       -79.356980
# 3                   El Catrin       43.650601       -79.358920
# 4  Cluny Bistro & Boulangerie       43.650565       -79.357843
#
#           Venue Category              Neighborhood
# 0  Portuguese Restaurant          Victoria Village
# 1      French Restaurant          Victoria Village
# 2             Restaurant  Harbourfront,Regent Park
# 3     Mexican Restaurant  Harbourfront,Regent Park
# 4      French Restaurant  Harbourfront,Regent Park

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="Toronto")
location = geolocator.geocode(address)
latitude_toronto = location.latitude
longitude_toronto = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude_toronto, longitude_toronto))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
map_restaurant = folium.Map(location=[latitude_toronto, longitude_toronto], zoom_start=10)

# add markers to map
for lat, lng, borough, Neighborhood in zip(toronto_rest['Venue Latitude'], toronto_rest['Venue Longitude'],toronto_rest['Borough'], toronto_rest['Neighborhood']):
    label = '{}, {}'.format(Neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_restaurant)  
    
map_restaurant
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
toronto_onehot = pd.get_dummies(toronto_rest[['Venue Category']], prefix = "", prefix_sep = "")
toronto_onehot ['Neighborhood'] = toronto_rest['Neighborhood']
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %%
num_top_venues = 10

for neigh in toronto_grouped['Neighborhood']:
  print("----" + neigh + "----")
  temp = toronto_grouped[toronto_grouped['Neighborhood'] == neigh].T.reset_index()
  temp.columns = ['venue', 'freq']
  temp = temp.iloc[1:]
  temp['freq'] = temp['freq'].astype(float)
  temp = temp.round({'freq': 2})
  print(temp.sort_values('freq', ascending = False).reset_index(drop = True).head(num_top_venues))
  print('\n')
# Out:
# ----Adelaide,King,Richmond----
#                            venue  freq
# 0                Thai Restaurant  0.14
# 1            American Restaurant  0.14
# 2               Asian Restaurant  0.10
# 3                     Restaurant  0.10
# 4               Sushi Restaurant  0.07
# 5  Vegetarian / Vegan Restaurant  0.07
# 6             Seafood Restaurant  0.03
# 7        New American Restaurant  0.03
# 8               Greek Restaurant  0.03
# 9      Latin American Restaurant  0.03
#
#
# ----Agincourt----
#                        venue  freq
# 0         Chinese Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2          Polish Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Albion Gardens,Beaumond Heights,Humbergate,Jamestown,Mount Olive,Silverstone,South Steeles,Thistletown----
#                        venue  freq
# 0       Fast Food Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Bathurst Manor,Downsview North,Wilson Heights----
#                        venue  freq
# 0           Sushi Restaurant  0.25
# 1  Middle Eastern Restaurant  0.25
# 2                 Restaurant  0.25
# 3       Fast Food Restaurant  0.25
# 4          Afghan Restaurant  0.00
# 5    New American Restaurant  0.00
# 6          Jewish Restaurant  0.00
# 7          Korean Restaurant  0.00
# 8  Latin American Restaurant  0.00
# 9           Malay Restaurant  0.00
#
#
# ----Bayview Village----
#                        venue  freq
# 0        Japanese Restaurant   0.5
# 1         Chinese Restaurant   0.5
# 2          Polish Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Bedford Park,Lawrence Manor East----
#                      venue  freq
# 0       Italian Restaurant   0.2
# 1     Fast Food Restaurant   0.1
# 2      American Restaurant   0.1
# 3          Thai Restaurant   0.1
# 4        Indian Restaurant   0.1
# 5         Sushi Restaurant   0.1
# 6  Comfort Food Restaurant   0.1
# 7         Greek Restaurant   0.1
# 8               Restaurant   0.1
# 9       Mexican Restaurant   0.0
#
#
# ----Berczy Park----
#                            venue  freq
# 0             Seafood Restaurant  0.18
# 1        Comfort Food Restaurant  0.09
# 2                     Restaurant  0.09
# 3  Vegetarian / Vegan Restaurant  0.09
# 4             Belgian Restaurant  0.09
# 5             Italian Restaurant  0.09
# 6                Thai Restaurant  0.09
# 7              French Restaurant  0.09
# 8              Indian Restaurant  0.09
# 9               Greek Restaurant  0.09
#
#
# ----Brockton,Exhibition Place,Parkdale Village----
#                        venue  freq
# 0       Caribbean Restaurant  0.33
# 1                 Restaurant  0.33
# 2         Italian Restaurant  0.33
# 3          Afghan Restaurant  0.00
# 4         Persian Restaurant  0.00
# 5          Jewish Restaurant  0.00
# 6          Korean Restaurant  0.00
# 7  Latin American Restaurant  0.00
# 8           Malay Restaurant  0.00
# 9   Mediterranean Restaurant  0.00
#
#
# ----Business Reply Mail Processing Centre 969 Eastern----
#                        venue  freq
# 0       Fast Food Restaurant   0.5
# 1                 Restaurant   0.5
# 2          Afghan Restaurant   0.0
# 3         Persian Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9         Mexican Restaurant   0.0
#
#
# ----Cabbagetown,St. James Town----
#                              venue  freq
# 0                       Restaurant  0.27
# 1               Italian Restaurant  0.18
# 2             Caribbean Restaurant  0.09
# 3              Japanese Restaurant  0.09
# 4               Chinese Restaurant  0.09
# 5             Taiwanese Restaurant  0.09
# 6                  Thai Restaurant  0.09
# 7                Indian Restaurant  0.09
# 8                Korean Restaurant  0.00
# 9  Molecular Gastronomy Restaurant  0.00
#
#
# ----Caledonia-Fairbanks----
#                        venue  freq
# 0       Fast Food Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Canada Post Gateway Processing Centre----
#                        venue  freq
# 0   Mediterranean Restaurant  0.33
# 1  Middle Eastern Restaurant  0.33
# 2        American Restaurant  0.33
# 3          Afghan Restaurant  0.00
# 4         Persian Restaurant  0.00
# 5        Japanese Restaurant  0.00
# 6          Jewish Restaurant  0.00
# 7          Korean Restaurant  0.00
# 8  Latin American Restaurant  0.00
# 9           Malay Restaurant  0.00
#
#
# ----Cedarbrae----
#                        venue  freq
# 0            Thai Restaurant  0.33
# 1           Hakka Restaurant  0.33
# 2       Caribbean Restaurant  0.33
# 3          Afghan Restaurant  0.00
# 4         Persian Restaurant  0.00
# 5          Jewish Restaurant  0.00
# 6          Korean Restaurant  0.00
# 7  Latin American Restaurant  0.00
# 8           Malay Restaurant  0.00
# 9   Mediterranean Restaurant  0.00
#
#
# ----Central Bay Street----
#                        venue  freq
# 0         Italian Restaurant  0.19
# 1        Japanese Restaurant  0.10
# 2          French Restaurant  0.05
# 3  Middle Eastern Restaurant  0.05
# 4         Falafel Restaurant  0.05
# 5          Korean Restaurant  0.05
# 6   Mediterranean Restaurant  0.05
# 7      Portuguese Restaurant  0.05
# 8           Ramen Restaurant  0.05
# 9         Seafood Restaurant  0.05
#
#
# ----Chinatown,Grange Park,Kensington Market----
#                            venue  freq
# 0  Vegetarian / Vegan Restaurant  0.18
# 1             Chinese Restaurant  0.15
# 2          Vietnamese Restaurant  0.12
# 3             Mexican Restaurant  0.09
# 4            Dumpling Restaurant  0.09
# 5        Comfort Food Restaurant  0.06
# 6             Dim Sum Restaurant  0.03
# 7            Filipino Restaurant  0.03
# 8               Ramen Restaurant  0.03
# 9              Hotpot Restaurant  0.03
#
#
# ----Christie----
#                        venue  freq
# 0         Italian Restaurant   0.5
# 1                 Restaurant   0.5
# 2         Persian Restaurant   0.0
# 3        Japanese Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9         Mexican Restaurant   0.0
#
#
# ----Church and Wellesley----
#                       venue  freq
# 0          Sushi Restaurant  0.14
# 1       Japanese Restaurant  0.14
# 2                Restaurant  0.11
# 3  Mediterranean Restaurant  0.07
# 4       American Restaurant  0.07
# 5         Afghan Restaurant  0.04
# 6      Fast Food Restaurant  0.04
# 7          Theme Restaurant  0.04
# 8           Thai Restaurant  0.04
# 9        Seafood Restaurant  0.04
#
#
# ----Clairlea,Golden Mile,Oakridge----
#                        venue  freq
# 0       Fast Food Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Clarks Corners,Sullivan,Tam O'Shanter----
#                        venue  freq
# 0            Thai Restaurant  0.25
# 1         Chinese Restaurant  0.25
# 2       Fast Food Restaurant  0.25
# 3         Italian Restaurant  0.25
# 4          Afghan Restaurant  0.00
# 5    New American Restaurant  0.00
# 6          Jewish Restaurant  0.00
# 7          Korean Restaurant  0.00
# 8  Latin American Restaurant  0.00
# 9           Malay Restaurant  0.00
#
#
# ----Cliffcrest,Cliffside,Scarborough Village West----
#                        venue  freq
# 0        American Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3        Japanese Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9         Mexican Restaurant   0.0
#
#
# ----Commerce Court,Victoria Hotel----
#                            venue  freq
# 0                     Restaurant  0.18
# 1            American Restaurant  0.14
# 2             Seafood Restaurant  0.11
# 3             Italian Restaurant  0.11
# 4  Vegetarian / Vegan Restaurant  0.07
# 5            Japanese Restaurant  0.07
# 6                Thai Restaurant  0.07
# 7      Latin American Restaurant  0.04
# 8        New American Restaurant  0.04
# 9         Gluten-free Restaurant  0.04
#
#
# ----Davisville----
#                  venue  freq
# 0   Italian Restaurant  0.18
# 1     Sushi Restaurant  0.18
# 2  Japanese Restaurant  0.09
# 3           Restaurant  0.09
# 4   Seafood Restaurant  0.09
# 5     Greek Restaurant  0.09
# 6      Thai Restaurant  0.09
# 7    Indian Restaurant  0.09
# 8  American Restaurant  0.09
# 9    Korean Restaurant  0.00
#
#
# ----Deer Park,Forest Hill SE,Rathnelly,South Hill,Summerhill West----
#                        venue  freq
# 0      Vietnamese Restaurant  0.25
# 1           Sushi Restaurant  0.25
# 2                 Restaurant  0.25
# 3        American Restaurant  0.25
# 4    New American Restaurant  0.00
# 5        Japanese Restaurant  0.00
# 6          Jewish Restaurant  0.00
# 7          Korean Restaurant  0.00
# 8  Latin American Restaurant  0.00
# 9           Malay Restaurant  0.00
#
#
# ----Del Ray,Keelesdale,Mount Dennis,Silverthorn----
#                        venue  freq
# 0                 Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3        Japanese Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9         Mexican Restaurant   0.0
#
#
# ----Design Exchange,Toronto Dominion Centre----
#                            venue  freq
# 0                     Restaurant  0.17
# 1             Italian Restaurant  0.13
# 2            American Restaurant  0.13
# 3            Japanese Restaurant  0.09
# 4             Seafood Restaurant  0.09
# 5           Fast Food Restaurant  0.04
# 6         Gluten-free Restaurant  0.04
# 7               Asian Restaurant  0.04
# 8  Vegetarian / Vegan Restaurant  0.04
# 9                Thai Restaurant  0.04
#
#
# ----Don Mills North----
#                        venue  freq
# 0        Japanese Restaurant   0.5
# 1       Caribbean Restaurant   0.5
# 2          Polish Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Dorset Park,Scarborough Town Centre,Wexford Heights----
#                        venue  freq
# 0          Indian Restaurant   0.4
# 1      Vietnamese Restaurant   0.2
# 2  Latin American Restaurant   0.2
# 3         Chinese Restaurant   0.2
# 4         Persian Restaurant   0.0
# 5          Jewish Restaurant   0.0
# 6          Korean Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9         Mexican Restaurant   0.0
#
#
# ----Dovercourt Village,Dufferin----
#                        venue  freq
# 0  Middle Eastern Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3        Japanese Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9         Mexican Restaurant   0.0
#
#
# ----Fairview,Henry Farm,Oriole----
#                        venue  freq
# 0       Fast Food Restaurant  0.38
# 1        Japanese Restaurant  0.15
# 2           Asian Restaurant  0.15
# 3        American Restaurant  0.08
# 4         Chinese Restaurant  0.08
# 5           Greek Restaurant  0.08
# 6                 Restaurant  0.08
# 7    New American Restaurant  0.00
# 8          Korean Restaurant  0.00
# 9  Latin American Restaurant  0.00
#
#
# ----First Canadian Place,Underground city----
#                       venue  freq
# 0                Restaurant  0.16
# 1       American Restaurant  0.12
# 2          Asian Restaurant  0.12
# 3        Seafood Restaurant  0.12
# 4       Japanese Restaurant  0.08
# 5           Thai Restaurant  0.08
# 6  Mediterranean Restaurant  0.04
# 7    Gluten-free Restaurant  0.04
# 8          Greek Restaurant  0.04
# 9   New American Restaurant  0.04
#
#
# ----Flemingdon Park,Don Mills South----
#                        venue  freq
# 0           Asian Restaurant  0.25
# 1        Japanese Restaurant  0.12
# 2         Chinese Restaurant  0.12
# 3                 Restaurant  0.12
# 4         Dim Sum Restaurant  0.12
# 5       Fast Food Restaurant  0.12
# 6         Italian Restaurant  0.12
# 7           Malay Restaurant  0.00
# 8  Latin American Restaurant  0.00
# 9         Persian Restaurant  0.00
#
#
# ----Forest Hill North,Forest Hill West----
#                        venue  freq
# 0           Sushi Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3        Japanese Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9         Mexican Restaurant   0.0
#
#
# ----Glencairn----
#                        venue  freq
# 0        Japanese Restaurant   0.5
# 1           Sushi Restaurant   0.5
# 2          Afghan Restaurant   0.0
# 3         Persian Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9         Mexican Restaurant   0.0
#
#
# ----Guildwood,Morningside,West Hill----
#                        venue  freq
# 0         Mexican Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3        Japanese Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Harbord,University of Toronto----
#                       venue  freq
# 0        Italian Restaurant   0.2
# 1       Japanese Restaurant   0.2
# 2                Restaurant   0.2
# 3        Chinese Restaurant   0.1
# 4         French Restaurant   0.1
# 5   Comfort Food Restaurant   0.1
# 6          Sushi Restaurant   0.1
# 7  Mediterranean Restaurant   0.0
# 8   New American Restaurant   0.0
# 9          Malay Restaurant   0.0
#
#
# ----Harbourfront East,Toronto Islands,Union Station----
#                            venue  freq
# 0             Italian Restaurant  0.17
# 1                     Restaurant  0.17
# 2            Japanese Restaurant  0.08
# 3             Chinese Restaurant  0.08
# 4             Mexican Restaurant  0.08
# 5             Seafood Restaurant  0.08
# 6               Sushi Restaurant  0.08
# 7              Indian Restaurant  0.08
# 8  Vegetarian / Vegan Restaurant  0.08
# 9        New American Restaurant  0.08
#
#
# ----Harbourfront,Regent Park----
#                        venue  freq
# 0         Mexican Restaurant  0.29
# 1                 Restaurant  0.29
# 2           Greek Restaurant  0.14
# 3          French Restaurant  0.14
# 4         Italian Restaurant  0.14
# 5          Afghan Restaurant  0.00
# 6    New American Restaurant  0.00
# 7          Jewish Restaurant  0.00
# 8          Korean Restaurant  0.00
# 9  Latin American Restaurant  0.00
#
#
# ----High Park,The Junction South----
#                        venue  freq
# 0            Thai Restaurant  0.29
# 1         Mexican Restaurant  0.29
# 2  Cajun / Creole Restaurant  0.14
# 3       Fast Food Restaurant  0.14
# 4         Italian Restaurant  0.14
# 5          Afghan Restaurant  0.00
# 6    New American Restaurant  0.00
# 7          Jewish Restaurant  0.00
# 8          Korean Restaurant  0.00
# 9  Latin American Restaurant  0.00
#
#
# ----Hillcrest Village----
#                        venue  freq
# 0   Mediterranean Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3        Japanese Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Humber Bay Shores,Mimico South,New Toronto----
#                        venue  freq
# 0        American Restaurant  0.25
# 1         Seafood Restaurant  0.25
# 2                 Restaurant  0.25
# 3       Fast Food Restaurant  0.25
# 4    New American Restaurant  0.00
# 5        Japanese Restaurant  0.00
# 6          Jewish Restaurant  0.00
# 7          Korean Restaurant  0.00
# 8  Latin American Restaurant  0.00
# 9           Malay Restaurant  0.00
#
#
# ----Humber Summit----
#                        venue  freq
# 0        Empanada Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Kingsway Park South West,Mimico NW,The Queensway West,Royal York South West,South of Bloor----
#                        venue  freq
# 0       Fast Food Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----L'Amoreaux West----
#                        venue  freq
# 0         Chinese Restaurant   0.5
# 1       Fast Food Restaurant   0.5
# 2          Afghan Restaurant   0.0
# 3         Persian Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9         Mexican Restaurant   0.0
#
#
# ----Lawrence Heights,Lawrence Manor----
#                        venue  freq
# 0      Vietnamese Restaurant   1.0
# 1         Persian Restaurant   0.0
# 2        Japanese Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Leaside----
#                        venue  freq
# 0           Sushi Restaurant  0.33
# 1         Mexican Restaurant  0.33
# 2                 Restaurant  0.33
# 3          Afghan Restaurant  0.00
# 4    New American Restaurant  0.00
# 5        Japanese Restaurant  0.00
# 6          Jewish Restaurant  0.00
# 7          Korean Restaurant  0.00
# 8  Latin American Restaurant  0.00
# 9           Malay Restaurant  0.00
#
#
# ----Little Portugal,Trinity----
#                              venue  freq
# 0                 Asian Restaurant  0.15
# 1            Vietnamese Restaurant  0.10
# 2                French Restaurant  0.10
# 3          New American Restaurant  0.10
# 4                       Restaurant  0.10
# 5  Southern / Soul Food Restaurant  0.05
# 6               Italian Restaurant  0.05
# 7                 Malay Restaurant  0.05
# 8                 Greek Restaurant  0.05
# 9                Korean Restaurant  0.05
#
#
# ----Maryvale,Wexford----
#                        venue  freq
# 0  Middle Eastern Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3        Japanese Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9         Mexican Restaurant   0.0
#
#
# ----North Toronto West----
#                        venue  freq
# 0         Chinese Restaurant  0.33
# 1         Mexican Restaurant  0.33
# 2                 Restaurant  0.33
# 3          Afghan Restaurant  0.00
# 4         Persian Restaurant  0.00
# 5          Jewish Restaurant  0.00
# 6          Korean Restaurant  0.00
# 7  Latin American Restaurant  0.00
# 8           Malay Restaurant  0.00
# 9   Mediterranean Restaurant  0.00
#
#
# ----Northwood Park,York University----
#                        venue  freq
# 0       Caribbean Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2          Polish Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Parkdale,Roncesvalles----
#                          venue  freq
# 0  Eastern European Restaurant  0.25
# 1             Cuban Restaurant  0.25
# 2                   Restaurant  0.25
# 3           Italian Restaurant  0.25
# 4           Persian Restaurant  0.00
# 5            Jewish Restaurant  0.00
# 6            Korean Restaurant  0.00
# 7    Latin American Restaurant  0.00
# 8             Malay Restaurant  0.00
# 9     Mediterranean Restaurant  0.00
#
#
# ----Rouge,Malvern----
#                        venue  freq
# 0       Fast Food Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Runnymede,Swansea----
#                              venue  freq
# 0                 Sushi Restaurant   0.2
# 1                       Restaurant   0.2
# 2               Italian Restaurant   0.2
# 3    Vegetarian / Vegan Restaurant   0.1
# 4        Latin American Restaurant   0.1
# 5                French Restaurant   0.1
# 6               Falafel Restaurant   0.1
# 7                Afghan Restaurant   0.0
# 8  Molecular Gastronomy Restaurant   0.0
# 9                Jewish Restaurant   0.0
#
#
# ----Ryerson,Garden District----
#                         venue  freq
# 0        Fast Food Restaurant  0.14
# 1         Japanese Restaurant  0.10
# 2          Italian Restaurant  0.10
# 3   Middle Eastern Restaurant  0.10
# 4            Ramen Restaurant  0.10
# 5                  Restaurant  0.05
# 6         American Restaurant  0.05
# 7          Mexican Restaurant  0.05
# 8  Modern European Restaurant  0.05
# 9        Ethiopian Restaurant  0.05
#
#
# ----St. James Town----
#                        venue  freq
# 0         Italian Restaurant  0.20
# 1                 Restaurant  0.20
# 2        Japanese Restaurant  0.08
# 3         Seafood Restaurant  0.08
# 4        American Restaurant  0.08
# 5    New American Restaurant  0.04
# 6          French Restaurant  0.04
# 7          German Restaurant  0.04
# 8  Middle Eastern Restaurant  0.04
# 9    Comfort Food Restaurant  0.04
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#                      venue  freq
# 0               Restaurant  0.18
# 1       Italian Restaurant  0.14
# 2       Seafood Restaurant  0.14
# 3     Fast Food Restaurant  0.14
# 4      Japanese Restaurant  0.09
# 5        Indian Restaurant  0.05
# 6        French Restaurant  0.05
# 7  Comfort Food Restaurant  0.05
# 8          Thai Restaurant  0.05
# 9       Belgian Restaurant  0.05
#
#
# ----Studio District----
#                        venue  freq
# 0         Italian Restaurant   0.2
# 1        American Restaurant   0.2
# 2            Thai Restaurant   0.1
# 3  Latin American Restaurant   0.1
# 4         Chinese Restaurant   0.1
# 5    Comfort Food Restaurant   0.1
# 6         Seafood Restaurant   0.1
# 7  Middle Eastern Restaurant   0.1
# 8    New American Restaurant   0.0
# 9          Jewish Restaurant   0.0
#
#
# ----The Annex,North Midtown,Yorkville----
#                            venue  freq
# 0            American Restaurant  0.25
# 1  Vegetarian / Vegan Restaurant  0.25
# 2              Indian Restaurant  0.25
# 3              Jewish Restaurant  0.25
# 4        New American Restaurant  0.00
# 5            Japanese Restaurant  0.00
# 6              Korean Restaurant  0.00
# 7      Latin American Restaurant  0.00
# 8               Malay Restaurant  0.00
# 9       Mediterranean Restaurant  0.00
#
#
# ----The Beaches West,India Bazaar----
#                        venue  freq
# 0           Sushi Restaurant  0.33
# 1       Fast Food Restaurant  0.33
# 2         Italian Restaurant  0.33
# 3          Afghan Restaurant  0.00
# 4    New American Restaurant  0.00
# 5          Jewish Restaurant  0.00
# 6          Korean Restaurant  0.00
# 7  Latin American Restaurant  0.00
# 8           Malay Restaurant  0.00
# 9   Mediterranean Restaurant  0.00
#
#
# ----The Danforth West,Riverdale----
#                        venue  freq
# 0           Greek Restaurant  0.53
# 1         Italian Restaurant  0.20
# 2        American Restaurant  0.07
# 3          Indian Restaurant  0.07
# 4       Caribbean Restaurant  0.07
# 5                 Restaurant  0.07
# 6    New American Restaurant  0.00
# 7          Korean Restaurant  0.00
# 8  Latin American Restaurant  0.00
# 9           Malay Restaurant  0.00
#
#
# ----The Junction North,Runnymede----
#                        venue  freq
# 0       Caribbean Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2          Polish Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Thorncliffe Park----
#                        venue  freq
# 0          Indian Restaurant   1.0
# 1         Persian Restaurant   0.0
# 2        Japanese Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Victoria Village----
#                        venue  freq
# 0          French Restaurant   0.5
# 1      Portuguese Restaurant   0.5
# 2          Afghan Restaurant   0.0
# 3         Persian Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9         Mexican Restaurant   0.0
#
#
# ----Westmount----
#                        venue  freq
# 0         Chinese Restaurant   0.5
# 1  Middle Eastern Restaurant   0.5
# 2          Afghan Restaurant   0.0
# 3          Polish Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5          Korean Restaurant   0.0
# 6  Latin American Restaurant   0.0
# 7           Malay Restaurant   0.0
# 8   Mediterranean Restaurant   0.0
# 9         Mexican Restaurant   0.0
#
#
# ----Willowdale South----
#                        venue  freq
# 0           Ramen Restaurant  0.27
# 1                 Restaurant  0.18
# 2      Indonesian Restaurant  0.09
# 3       Fast Food Restaurant  0.09
# 4           Sushi Restaurant  0.09
# 5  Middle Eastern Restaurant  0.09
# 6        Japanese Restaurant  0.09
# 7      Vietnamese Restaurant  0.09
# 8       Colombian Restaurant  0.00
# 9      Portuguese Restaurant  0.00
#
#
# ----Woburn----
#                        venue  freq
# 0          Korean Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3        Japanese Restaurant   0.0
# 4          Jewish Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0
#
#
# ----Woodbine Gardens,Parkview Hill----
#                        venue  freq
# 0       Fast Food Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2         Persian Restaurant   0.0
# 3          Jewish Restaurant   0.0
# 4          Korean Restaurant   0.0
# 5  Latin American Restaurant   0.0
# 6           Malay Restaurant   0.0
# 7   Mediterranean Restaurant   0.0
# 8         Mexican Restaurant   0.0
# 9  Middle Eastern Restaurant   0.0

# %%
# Define a function to sort the venues in descending order.

def return_most_common_venues(row, num_top_venues):
  row_categories = row.iloc[1:]
  row_categories_sorted = row_categories.sort_values(ascending = False)

  return row_categories_sorted.index.values[0:num_top_venues]

# %%
# Creat a new dataframe for venues sorted
import numpy as np
num_top_venues = 10
indicators = ['st', 'nd', 'rd']

# Creat columns according to the number of top venues
columns = ['Neighborhood']
for i in np.arange(num_top_venues):
  try:
    columns.append('{}{} Most Common Venue'.format(i+1, indicators[i]))
  except:
    columns.append('{}th most Common Venue'.format(i+1))

# Creat a new dataframe
neighborhood_venues_sorted = pd.DataFrame(columns = columns)
neighborhood_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for i in np.arange(toronto_grouped.shape[0]):
  neighborhood_venues_sorted.iloc[i,1:] = return_most_common_venues(toronto_grouped.iloc[i, :], num_top_venues)

neighborhood_venues_sorted.head(10)
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                             Adelaide,King,Richmond   American Restaurant
# 1                                          Agincourt    Chinese Restaurant
# 2  Albion Gardens,Beaumond Heights,Humbergate,Jam...  Fast Food Restaurant
# 3      Bathurst Manor,Downsview North,Wilson Heights      Sushi Restaurant
# 4                                    Bayview Village   Japanese Restaurant
# 5                   Bedford Park,Lawrence Manor East    Italian Restaurant
# 6                                        Berczy Park    Seafood Restaurant
# 7         Brockton,Exhibition Place,Parkdale Village    Italian Restaurant
# 8  Business Reply Mail Processing Centre 969 Eastern  Fast Food Restaurant
# 9                         Cabbagetown,St. James Town            Restaurant
#
#    2nd Most Common Venue  3rd Most Common Venue      4th most Common Venue  \
# 0        Thai Restaurant       Asian Restaurant                 Restaurant
# 1  Vietnamese Restaurant    Dumpling Restaurant           Hakka Restaurant
# 2  Vietnamese Restaurant    Dumpling Restaurant           Hakka Restaurant
# 3   Fast Food Restaurant             Restaurant  Middle Eastern Restaurant
# 4     Chinese Restaurant  Vietnamese Restaurant        Dumpling Restaurant
# 5      Indian Restaurant       Sushi Restaurant       Fast Food Restaurant
# 6     Italian Restaurant       Greek Restaurant    Comfort Food Restaurant
# 7   Caribbean Restaurant             Restaurant      Vietnamese Restaurant
# 8             Restaurant  Vietnamese Restaurant           Doner Restaurant
# 9     Italian Restaurant      Indian Restaurant            Thai Restaurant
#
#      5th most Common Venue          6th most Common Venue  \
# 0         Sushi Restaurant  Vegetarian / Vegan Restaurant
# 1         Greek Restaurant         Gluten-free Restaurant
# 2         Greek Restaurant         Gluten-free Restaurant
# 3    Vietnamese Restaurant               Doner Restaurant
# 4         Greek Restaurant         Gluten-free Restaurant
# 5  Comfort Food Restaurant                     Restaurant
# 6               Restaurant              French Restaurant
# 7      Dumpling Restaurant               Greek Restaurant
# 8         Greek Restaurant         Gluten-free Restaurant
# 9     Taiwanese Restaurant            Japanese Restaurant
#
#     7th most Common Venue 8th most Common Venue     9th most Common Venue  \
# 0       Indian Restaurant  Colombian Restaurant  Mediterranean Restaurant
# 1       German Restaurant     French Restaurant       Filipino Restaurant
# 2       German Restaurant     French Restaurant       Filipino Restaurant
# 3  Gluten-free Restaurant     German Restaurant         French Restaurant
# 4       German Restaurant     French Restaurant       Filipino Restaurant
# 5        Greek Restaurant   American Restaurant           Thai Restaurant
# 6       Indian Restaurant    Belgian Restaurant           Thai Restaurant
# 7  Gluten-free Restaurant     German Restaurant         French Restaurant
# 8       German Restaurant     French Restaurant       Filipino Restaurant
# 9    Caribbean Restaurant    Chinese Restaurant      Fast Food Restaurant
#
#           10th most Common Venue
# 0            Japanese Restaurant
# 1           Fast Food Restaurant
# 2             Falafel Restaurant
# 3            Filipino Restaurant
# 4           Fast Food Restaurant
# 5           Brazilian Restaurant
# 6  Vegetarian / Vegan Restaurant
# 7            Filipino Restaurant
# 8             Falafel Restaurant
# 9            Empanada Restaurant

# %% [markdown]
# ### Cluster Neighborhood

# %%
# Import libraries
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist

toronto_clustering = toronto_grouped.drop('Neighborhood',1)

# %%
K = range(1, 10)
distortions = []
for k in K:
  kmeans = KMeans(init = 'k-means++', n_clusters=k, n_init = 12, random_state=0)
  kmeans.fit(toronto_clustering.values.reshape(-1, 1))
  distortions.append(sum(np.min(cdist(toronto_clustering.values.reshape(-1, 1),
                                        kmeans.cluster_centers_, 'euclidean'), axis=1)) / toronto_clustering.shape [0])

import matplotlib.pyplot as plt
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# Refer to the elbow method, the optimal value of the number of cluster should be defined as 5.

# %%
num_clusters = 7

kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(toronto_clustering)
kmeans.labels_
# Out:
# array([5, 0, 3, 5, 0, 5, 5, 5, 5, 5, 3, 6, 5, 5, 5, 5, 5, 3, 5, 6, 5, 5,
#        5, 5, 5, 2, 1, 6, 5, 5, 5, 4, 4, 0, 5, 5, 5, 5, 6, 5, 1, 3, 0, 1,
#        5, 5, 6, 0, 2, 5, 3, 5, 5, 5, 5, 5, 1, 5, 5, 2, 1, 1, 6, 5, 1, 3],
#       dtype=int32)

# %% [markdown]
# Right now, we need to creat a new dataframe that includeds the cluster for each neighborhood.

# %%
# Add clusterin labels
neighborhood_venues_sorted.insert(0, 'Cluster', kmeans.labels_)
toronto_merge = df_merge

# Merge toronto_grouped with df_merge
toronto_merge = toronto_merge.join(neighborhood_venues_sorted.set_index('Neighborhood'), on = 'Neighborhood')

toronto_merge.head()
# Out:
#   PostalCode           Borough                     Neighborhood   Latitude  \
# 0        M3A        North York                        Parkwoods  43.753259
# 1        M4A        North York                 Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Harbourfront,Regent Park  43.654260
# 3        M6A        North York  Lawrence Heights,Lawrence Manor  43.718518
# 4        M9A         Etobicoke                 Islington Avenue  43.667856
#
#    Longitude  Cluster  1st Most Common Venue  2nd Most Common Venue  \
# 0 -79.329656      NaN                    NaN                    NaN
# 1 -79.315572      1.0      French Restaurant  Portuguese Restaurant
# 2 -79.360636      5.0             Restaurant     Mexican Restaurant
# 3 -79.464763      1.0  Vietnamese Restaurant    Dumpling Restaurant
# 4 -79.532242      NaN                    NaN                    NaN
#
#    3rd Most Common Venue 4th most Common Venue   5th most Common Venue  \
# 0                    NaN                   NaN                     NaN
# 1  Vietnamese Restaurant      Doner Restaurant        Greek Restaurant
# 2       Greek Restaurant    Italian Restaurant       French Restaurant
# 3       Hakka Restaurant      Greek Restaurant  Gluten-free Restaurant
# 4                    NaN                   NaN                     NaN
#
#     6th most Common Venue   7th most Common Venue 8th most Common Venue  \
# 0                     NaN                     NaN                   NaN
# 1  Gluten-free Restaurant       German Restaurant   Filipino Restaurant
# 2     Dumpling Restaurant  Gluten-free Restaurant     German Restaurant
# 3       German Restaurant       French Restaurant   Filipino Restaurant
# 4                     NaN                     NaN                   NaN
#
#   9th most Common Venue 10th most Common Venue
# 0                   NaN                    NaN
# 1  Fast Food Restaurant     Falafel Restaurant
# 2   Filipino Restaurant   Fast Food Restaurant
# 3  Fast Food Restaurant     Falafel Restaurant
# 4                   NaN                    NaN

# %% [markdown]
# We observe that there is NaN for some neighborhood and one more cluster label columns. Drop them.

# %%
toronto_merge = toronto_merge.dropna()

# %%
toronto_merge['Cluster'] = toronto_merge.Cluster.astype(int)

# %%
# Import libraries
import matplotlib.cm as cm
import matplotlib.colors as colors

# Creat the folium map

map_toronto = folium.Map(location = [latitude_toronto, longitude_toronto], zoom_start=10)

# Set color for clusters
x = np.arange(num_clusters)
ys = [i + x +(i*x)**2 for i in range(num_clusters)]
colors_array = cm.rainbow(np.linspace(0,1,len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Set the marker for the map
markers_colors = []
for lat, lng, nei, cluster in zip(toronto_merge['Latitude'], toronto_merge['Longitude'], toronto_merge['Neighborhood'], toronto_merge['Cluster']):
  label = folium.Popup(str(nei) + ' Cluster ' + str(cluster), parse_html=True)
  folium.CircleMarker([lat, lng],
                      radius=5,
                      popup=label,
                      color=rainbow[cluster-1],
                      fill=True,
                      fill_color=rainbow[cluster-1],
                      fill_opacity=0.7).add_to(map_toronto)

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine Clusters

# %% [markdown]
# #### For Cluster 1

# %%
toronto_merge.loc[toronto_merge['Cluster'] == 0, toronto_merge.columns[[1] + list(range(7, toronto_merge.shape[1]))]]
# Out:
#             Borough  2nd Most Common Venue  3rd Most Common Venue  \
# 17      Scarborough  Vietnamese Restaurant    Dumpling Restaurant
# 38       North York     Chinese Restaurant  Vietnamese Restaurant
# 72  Central Toronto             Restaurant     Mexican Restaurant
# 77      Scarborough  Vietnamese Restaurant    Dumpling Restaurant
# 89      Scarborough   Fast Food Restaurant  Vietnamese Restaurant
#
#     4th most Common Venue   5th most Common Venue   6th most Common Venue  \
# 17       Greek Restaurant  Gluten-free Restaurant       German Restaurant
# 38    Dumpling Restaurant        Greek Restaurant  Gluten-free Restaurant
# 72  Vietnamese Restaurant     Dumpling Restaurant        Greek Restaurant
# 77       Hakka Restaurant        Greek Restaurant  Gluten-free Restaurant
# 89    Dumpling Restaurant        Hakka Restaurant        Greek Restaurant
#
#      7th most Common Venue 8th most Common Venue 9th most Common Venue  \
# 17       French Restaurant   Filipino Restaurant  Fast Food Restaurant
# 38       German Restaurant     French Restaurant   Filipino Restaurant
# 72  Gluten-free Restaurant     German Restaurant     French Restaurant
# 77       German Restaurant     French Restaurant   Filipino Restaurant
# 89  Gluten-free Restaurant     German Restaurant     French Restaurant
#
#    10th most Common Venue
# 17     Falafel Restaurant
# 38   Fast Food Restaurant
# 72    Filipino Restaurant
# 77   Fast Food Restaurant
# 89    Filipino Restaurant

# %% [markdown]
# #### For Cluster 2

# %%
toronto_merge.loc[toronto_merge['Cluster'] == 1, toronto_merge.columns[[1] + list(range(7, toronto_merge.shape[1]))]]
# Out:
#             Borough      2nd Most Common Venue          3rd Most Common Venue  \
# 1        North York      Portuguese Restaurant          Vietnamese Restaurant
# 3        North York        Dumpling Restaurant               Hakka Restaurant
# 21      Scarborough      Vietnamese Restaurant            Dumpling Restaurant
# 28        East York        Dumpling Restaurant               Hakka Restaurant
# 49       North York      Vietnamese Restaurant            Dumpling Restaurant
# 64      Scarborough  Latin American Restaurant             Chinese Restaurant
# 73  Central Toronto          Jewish Restaurant  Vegetarian / Vegan Restaurant
#
#     4th most Common Venue   5th most Common Venue   6th most Common Venue  \
# 1        Doner Restaurant        Greek Restaurant  Gluten-free Restaurant
# 3        Greek Restaurant  Gluten-free Restaurant       German Restaurant
# 21       Greek Restaurant  Gluten-free Restaurant       German Restaurant
# 28       Greek Restaurant  Gluten-free Restaurant       German Restaurant
# 49       Hakka Restaurant        Greek Restaurant  Gluten-free Restaurant
# 64  Vietnamese Restaurant        Tapas Restaurant        Doner Restaurant
# 73    American Restaurant        Asian Restaurant     Empanada Restaurant
#
#      7th most Common Venue 8th most Common Venue   9th most Common Venue  \
# 1        German Restaurant   Filipino Restaurant    Fast Food Restaurant
# 3        French Restaurant   Filipino Restaurant    Fast Food Restaurant
# 21       French Restaurant   Filipino Restaurant    Fast Food Restaurant
# 28       French Restaurant   Filipino Restaurant    Fast Food Restaurant
# 49       German Restaurant     French Restaurant     Filipino Restaurant
# 64  Gluten-free Restaurant     German Restaurant       French Restaurant
# 73        Hakka Restaurant      Greek Restaurant  Gluten-free Restaurant
#
#    10th most Common Venue
# 1      Falafel Restaurant
# 3      Falafel Restaurant
# 21     Falafel Restaurant
# 28     Falafel Restaurant
# 49   Fast Food Restaurant
# 64    Filipino Restaurant
# 73      German Restaurant

# %% [markdown]
# #### For Cluster 3

# %%
toronto_merge.loc[toronto_merge['Cluster'] == 2, toronto_merge.columns[[1] + list(range(7, toronto_merge.shape[1]))]]
# Out:
#        Borough  2nd Most Common Venue  3rd Most Common Venue  \
# 6   North York   Caribbean Restaurant  Vietnamese Restaurant
# 33  North York  Vietnamese Restaurant    Dumpling Restaurant
# 62        York  Vietnamese Restaurant    Dumpling Restaurant
#
#    4th most Common Venue 5th most Common Venue   6th most Common Venue  \
# 6    Dumpling Restaurant      Greek Restaurant  Gluten-free Restaurant
# 33      Hakka Restaurant      Greek Restaurant  Gluten-free Restaurant
# 62      Hakka Restaurant      Greek Restaurant  Gluten-free Restaurant
#
#    7th most Common Venue 8th most Common Venue 9th most Common Venue  \
# 6      German Restaurant     French Restaurant   Filipino Restaurant
# 33     German Restaurant     French Restaurant   Filipino Restaurant
# 62     German Restaurant     French Restaurant   Filipino Restaurant
#
#    10th most Common Venue
# 6    Fast Food Restaurant
# 33   Fast Food Restaurant
# 62   Fast Food Restaurant

# %% [markdown]
# #### For Cluster 4

# %%
toronto_merge.loc[toronto_merge['Cluster'] == 3, toronto_merge.columns[[1] + list(range(7, toronto_merge.shape[1]))]]
# Out:
#          Borough  2nd Most Common Venue 3rd Most Common Venue  \
# 5    Scarborough  Vietnamese Restaurant   Dumpling Restaurant
# 7      East York  Vietnamese Restaurant   Dumpling Restaurant
# 20          York  Vietnamese Restaurant   Dumpling Restaurant
# 43   Scarborough  Vietnamese Restaurant   Dumpling Restaurant
# 88     Etobicoke  Vietnamese Restaurant   Dumpling Restaurant
# 101    Etobicoke  Vietnamese Restaurant   Dumpling Restaurant
#
#     4th most Common Venue 5th most Common Venue   6th most Common Venue  \
# 5        Hakka Restaurant      Greek Restaurant  Gluten-free Restaurant
# 7        Hakka Restaurant      Greek Restaurant  Gluten-free Restaurant
# 20       Hakka Restaurant      Greek Restaurant  Gluten-free Restaurant
# 43       Hakka Restaurant      Greek Restaurant  Gluten-free Restaurant
# 88       Hakka Restaurant      Greek Restaurant  Gluten-free Restaurant
# 101      Hakka Restaurant      Greek Restaurant  Gluten-free Restaurant
#
#     7th most Common Venue 8th most Common Venue 9th most Common Venue  \
# 5       German Restaurant     French Restaurant   Filipino Restaurant
# 7       German Restaurant     French Restaurant   Filipino Restaurant
# 20      German Restaurant     French Restaurant   Filipino Restaurant
# 43      German Restaurant     French Restaurant   Filipino Restaurant
# 88      German Restaurant     French Restaurant   Filipino Restaurant
# 101     German Restaurant     French Restaurant   Filipino Restaurant
#
#     10th most Common Venue
# 5       Falafel Restaurant
# 7       Falafel Restaurant
# 20      Falafel Restaurant
# 43      Falafel Restaurant
# 88      Falafel Restaurant
# 101     Falafel Restaurant

# %% [markdown]
# #### For Cluster 5

# %%
toronto_merge.loc[toronto_merge['Cluster'] == 4, toronto_merge.columns[[1] + list(range(7, toronto_merge.shape[1]))]]
# Out:
#             Borough  2nd Most Common Venue  3rd Most Common Venue  \
# 9        North York       Sushi Restaurant  Vietnamese Restaurant
# 67  Central Toronto  Vietnamese Restaurant       Doner Restaurant
#
#    4th most Common Venue   5th most Common Venue   6th most Common Venue  \
# 9    Dumpling Restaurant        Greek Restaurant  Gluten-free Restaurant
# 67      Greek Restaurant  Gluten-free Restaurant       German Restaurant
#
#    7th most Common Venue 8th most Common Venue 9th most Common Venue  \
# 9      German Restaurant     French Restaurant   Filipino Restaurant
# 67     French Restaurant   Filipino Restaurant  Fast Food Restaurant
#
#    10th most Common Venue
# 9    Fast Food Restaurant
# 67     Falafel Restaurant

# %% [markdown]
# #### For Cluster 6

# %%
toronto_merge.loc[toronto_merge['Cluster'] == 5, toronto_merge.columns[[1] + list(range(7, toronto_merge.shape[1]))]]
# Out:
#              Borough  2nd Most Common Venue    3rd Most Common Venue  \
# 2   Downtown Toronto     Mexican Restaurant         Greek Restaurant
# 8   Downtown Toronto       Ramen Restaurant       Italian Restaurant
# 12        North York     Italian Restaurant      Japanese Restaurant
# 14  Downtown Toronto     Italian Restaurant      American Restaurant
# 19  Downtown Toronto     Italian Restaurant         Greek Restaurant
# 22         East York             Restaurant       Mexican Restaurant
# 23  Downtown Toronto    Japanese Restaurant        Indian Restaurant
# 24  Downtown Toronto             Restaurant    Vietnamese Restaurant
# 25       Scarborough        Thai Restaurant     Caribbean Restaurant
# 27        North York   Fast Food Restaurant               Restaurant
# 29  Downtown Toronto        Thai Restaurant         Asian Restaurant
# 32        North York       Asian Restaurant      Japanese Restaurant
# 35  Downtown Toronto     Italian Restaurant  New American Restaurant
# 36      West Toronto  Vietnamese Restaurant               Restaurant
# 40      East Toronto     Italian Restaurant        Indian Restaurant
# 41  Downtown Toronto    American Restaurant       Italian Restaurant
# 42      West Toronto   Caribbean Restaurant               Restaurant
# 46      East Toronto       Sushi Restaurant     Fast Food Restaurant
# 47  Downtown Toronto    American Restaurant       Seafood Restaurant
# 53      East Toronto     Italian Restaurant       Seafood Restaurant
# 54        North York      Indian Restaurant         Sushi Restaurant
# 55              York  Vietnamese Restaurant         Doner Restaurant
# 58        North York             Restaurant    Vietnamese Restaurant
# 68      West Toronto     Mexican Restaurant       Italian Restaurant
# 74      West Toronto             Restaurant         Cuban Restaurant
# 78   Central Toronto     Italian Restaurant        Indian Restaurant
# 79  Downtown Toronto    Japanese Restaurant               Restaurant
# 80      West Toronto       Sushi Restaurant               Restaurant
# 81       Scarborough     Italian Restaurant       Chinese Restaurant
# 83  Downtown Toronto     Chinese Restaurant    Vietnamese Restaurant
# 85   Central Toronto    American Restaurant         Sushi Restaurant
# 87         Etobicoke     Seafood Restaurant               Restaurant
# 91  Downtown Toronto     Italian Restaurant     Fast Food Restaurant
# 95  Downtown Toronto     Italian Restaurant        Indian Restaurant
# 96  Downtown Toronto    American Restaurant         Asian Restaurant
# 98  Downtown Toronto    Japanese Restaurant               Restaurant
# 99      East Toronto             Restaurant    Vietnamese Restaurant
#
#             4th most Common Venue      5th most Common Venue  \
# 2              Italian Restaurant          French Restaurant
# 8             Japanese Restaurant  Middle Eastern Restaurant
# 12             Chinese Restaurant                 Restaurant
# 14            Japanese Restaurant         Seafood Restaurant
# 19        Comfort Food Restaurant                 Restaurant
# 22          Vietnamese Restaurant           Doner Restaurant
# 23          Portuguese Restaurant         Falafel Restaurant
# 24            Dumpling Restaurant           Greek Restaurant
# 25            Dumpling Restaurant           Greek Restaurant
# 27      Middle Eastern Restaurant      Vietnamese Restaurant
# 29                     Restaurant           Sushi Restaurant
# 32            American Restaurant           Greek Restaurant
# 35             Chinese Restaurant        Japanese Restaurant
# 36              French Restaurant    New American Restaurant
# 40            American Restaurant       Caribbean Restaurant
# 41            Japanese Restaurant         Seafood Restaurant
# 42          Vietnamese Restaurant        Dumpling Restaurant
# 46          Vietnamese Restaurant        Dumpling Restaurant
# 47             Italian Restaurant            Thai Restaurant
# 53                Thai Restaurant  Latin American Restaurant
# 54           Fast Food Restaurant    Comfort Food Restaurant
# 55               Greek Restaurant     Gluten-free Restaurant
# 58      Middle Eastern Restaurant      Indonesian Restaurant
# 68      Cajun / Creole Restaurant       Fast Food Restaurant
# 74    Eastern European Restaurant      Vietnamese Restaurant
# 78               Greek Restaurant        Japanese Restaurant
# 79               Sushi Restaurant          French Restaurant
# 80  Vegetarian / Vegan Restaurant          French Restaurant
# 81           Fast Food Restaurant      Vietnamese Restaurant
# 83             Mexican Restaurant        Dumpling Restaurant
# 85                     Restaurant        Dumpling Restaurant
# 87           Fast Food Restaurant      Vietnamese Restaurant
# 91             Seafood Restaurant        Japanese Restaurant
# 95                Thai Restaurant       Taiwanese Restaurant
# 96             Seafood Restaurant            Thai Restaurant
# 98            American Restaurant   Mediterranean Restaurant
# 99               Doner Restaurant           Greek Restaurant
#
#             6th most Common Venue          7th most Common Venue  \
# 2             Dumpling Restaurant         Gluten-free Restaurant
# 8           Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 12           Fast Food Restaurant             Dim Sum Restaurant
# 14      Middle Eastern Restaurant              German Restaurant
# 19              French Restaurant              Indian Restaurant
# 22         Gluten-free Restaurant              German Restaurant
# 23  Vegetarian / Vegan Restaurant              Korean Restaurant
# 24         Gluten-free Restaurant              German Restaurant
# 25         Gluten-free Restaurant              German Restaurant
# 27               Doner Restaurant         Gluten-free Restaurant
# 29  Vegetarian / Vegan Restaurant              Indian Restaurant
# 32             Chinese Restaurant                     Restaurant
# 35             Mexican Restaurant             Seafood Restaurant
# 36             Italian Restaurant            Japanese Restaurant
# 40                     Restaurant    Eastern European Restaurant
# 41             Chinese Restaurant           Fast Food Restaurant
# 42               Greek Restaurant         Gluten-free Restaurant
# 46               Greek Restaurant         Gluten-free Restaurant
# 47            Japanese Restaurant  Vegetarian / Vegan Restaurant
# 53      Middle Eastern Restaurant        Comfort Food Restaurant
# 54                     Restaurant               Greek Restaurant
# 55              German Restaurant              French Restaurant
# 58               Sushi Restaurant            Japanese Restaurant
# 68          Vietnamese Restaurant            Dumpling Restaurant
# 74            Dumpling Restaurant               Greek Restaurant
# 78             Seafood Restaurant                     Restaurant
# 79             Chinese Restaurant        Comfort Food Restaurant
# 80      Latin American Restaurant             Falafel Restaurant
# 81            Dumpling Restaurant               Greek Restaurant
# 83        Comfort Food Restaurant              Hotpot Restaurant
# 85               Greek Restaurant         Gluten-free Restaurant
# 87            Dumpling Restaurant               Greek Restaurant
# 91              Indian Restaurant              French Restaurant
# 95            Japanese Restaurant           Caribbean Restaurant
# 96            Japanese Restaurant         Gluten-free Restaurant
# 98          Vietnamese Restaurant              Polish Restaurant
# 99         Gluten-free Restaurant              German Restaurant
#
#             8th most Common Venue        9th most Common Venue  \
# 2               German Restaurant          Filipino Restaurant
# 8            Ethiopian Restaurant           Mexican Restaurant
# 12          Vietnamese Restaurant  Eastern European Restaurant
# 14        New American Restaurant      Comfort Food Restaurant
# 19             Belgian Restaurant              Thai Restaurant
# 22              French Restaurant          Filipino Restaurant
# 23       Mediterranean Restaurant    Middle Eastern Restaurant
# 24              French Restaurant          Filipino Restaurant
# 25              French Restaurant          Filipino Restaurant
# 27              German Restaurant            French Restaurant
# 29           Colombian Restaurant     Mediterranean Restaurant
# 32          Vietnamese Restaurant  Eastern European Restaurant
# 35              Indian Restaurant             Sushi Restaurant
# 36              Korean Restaurant             Malay Restaurant
# 40         Gluten-free Restaurant            German Restaurant
# 41         Gluten-free Restaurant      New American Restaurant
# 42              German Restaurant            French Restaurant
# 46              German Restaurant            French Restaurant
# 47             Chinese Restaurant       Gluten-free Restaurant
# 53             Chinese Restaurant           Falafel Restaurant
# 54            American Restaurant              Thai Restaurant
# 55            Filipino Restaurant         Fast Food Restaurant
# 58           Fast Food Restaurant            German Restaurant
# 68         Gluten-free Restaurant            German Restaurant
# 74         Gluten-free Restaurant            German Restaurant
# 78                Thai Restaurant          American Restaurant
# 79          Vietnamese Restaurant  Eastern European Restaurant
# 80          Vietnamese Restaurant          Dumpling Restaurant
# 81         Gluten-free Restaurant            German Restaurant
# 83             Italian Restaurant          Japanese Restaurant
# 85              German Restaurant            French Restaurant
# 87         Gluten-free Restaurant            German Restaurant
# 91  Vegetarian / Vegan Restaurant      Comfort Food Restaurant
# 95             Chinese Restaurant         Fast Food Restaurant
# 96  Vegetarian / Vegan Restaurant           Italian Restaurant
# 98           Caribbean Restaurant         Fast Food Restaurant
# 99              French Restaurant          Filipino Restaurant
#
#              10th most Common Venue
# 2              Fast Food Restaurant
# 8                Chinese Restaurant
# 12           Gluten-free Restaurant
# 14                French Restaurant
# 19    Vegetarian / Vegan Restaurant
# 22             Fast Food Restaurant
# 23                French Restaurant
# 24             Fast Food Restaurant
# 25             Fast Food Restaurant
# 27              Filipino Restaurant
# 29              Japanese Restaurant
# 32           Gluten-free Restaurant
# 35    Vegetarian / Vegan Restaurant
# 36                 Cuban Restaurant
# 40                French Restaurant
# 41                 Greek Restaurant
# 42              Filipino Restaurant
# 46              Filipino Restaurant
# 47          New American Restaurant
# 53              Empanada Restaurant
# 54             Brazilian Restaurant
# 55               Falafel Restaurant
# 58                French Restaurant
# 68                French Restaurant
# 74                French Restaurant
# 78              Filipino Restaurant
# 79           Gluten-free Restaurant
# 80                German Restaurant
# 81                French Restaurant
# 83              Filipino Restaurant
# 85              Filipino Restaurant
# 87                French Restaurant
# 91  Molecular Gastronomy Restaurant
# 95              Empanada Restaurant
# 96          New American Restaurant
# 98               Italian Restaurant
# 99               Falafel Restaurant

# %% [markdown]
# #### For Cluster 7

# %%
toronto_merge.loc[toronto_merge['Cluster'] == 6, toronto_merge.columns[[1] + list(range(7, toronto_merge.shape[1]))]]
# Out:
#          Borough      2nd Most Common Venue      3rd Most Common Venue  \
# 26    North York      Vietnamese Restaurant        Dumpling Restaurant
# 30  West Toronto      Vietnamese Restaurant        Dumpling Restaurant
# 50   Scarborough      Vietnamese Restaurant        Dumpling Restaurant
# 69     Etobicoke  Middle Eastern Restaurant      Vietnamese Restaurant
# 70   Scarborough      Vietnamese Restaurant        Dumpling Restaurant
# 75   Mississauga   Mediterranean Restaurant  Middle Eastern Restaurant
#
#     4th most Common Venue        5th most Common Venue  \
# 26       Greek Restaurant       Gluten-free Restaurant
# 30       Greek Restaurant       Gluten-free Restaurant
# 50       Hakka Restaurant             Greek Restaurant
# 69    Dumpling Restaurant             Greek Restaurant
# 70       Greek Restaurant       Gluten-free Restaurant
# 75  Vietnamese Restaurant  Eastern European Restaurant
#
#      6th most Common Venue   7th most Common Venue 8th most Common Venue  \
# 26       German Restaurant       French Restaurant   Filipino Restaurant
# 30       German Restaurant       French Restaurant   Filipino Restaurant
# 50  Gluten-free Restaurant       German Restaurant     French Restaurant
# 69  Gluten-free Restaurant       German Restaurant     French Restaurant
# 70       German Restaurant       French Restaurant   Filipino Restaurant
# 75        Greek Restaurant  Gluten-free Restaurant     German Restaurant
#
#    9th most Common Venue 10th most Common Venue
# 26  Fast Food Restaurant     Falafel Restaurant
# 30  Fast Food Restaurant     Falafel Restaurant
# 50   Filipino Restaurant   Fast Food Restaurant
# 69   Filipino Restaurant   Fast Food Restaurant
# 70  Fast Food Restaurant     Falafel Restaurant
# 75     French Restaurant    Filipino Restaurant
